# %%
import os
dir_path = os.getcwd()
print("The directory of this script is:", dir_path)
root_path = os.path.dirname(dir_path)
print("The root directory is:", root_path)
# Out:
# The directory of this script is: c:\Users\HP\Desktop\Projects\NodeRAG\graphs
# The root directory is: c:\Users\HP\Desktop\Projects\NodeRAG

# %%
import pandas as pd
medical_responses = pd.read_parquet(f"{root_path}\\text_decomposition/medical_responses_cleaned.parquet")
novel_responses = pd.read_parquet(f"{root_path}\\text_decomposition/novel_responses_cleaned.parquet")

# %%
medical_responses
# Out:
#      index                                           response  \
# 0        0  [\n{\n"semantic_unit": "Basal cell skin cancer...
# 1        1  [\n{\n"semantic_unit": "The hypodermis, the de...
# 2        2  ```json\n[\n  {\n    "semantic_unit": "Basal c...
# 3        3  [\n{\n"semantic_unit": "Recurrence of basal ce...
# 4        4  [\n{\n"semantic_unit": "This section discusses...
# ..     ...                                                ...
# 549    549  [\n{\n"semantic_unit": "The patient is inquiri...
# 550    550  [\n{\n"semantic_unit": "The text presents a se...
# 551    551  [\n  {\n    "semantic_unit": "The text poses q...
# 552    552  [\n{\n"semantic_unit": "The patient is inquiri...
# 553    553  [\n{\n"semantic_unit": "A clinical trial is a ...
#
#                                       cleaned_response  \
# 0    [\n{\n"semantic_unit": "Basal cell skin cancer...
# 1    [\n{\n"semantic_unit": "The hypodermis, the de...
# 2    [\n  {\n    "semantic_unit": "Basal cell skin ...
# 3    [\n{\n"semantic_unit": "Recurrence of basal ce...
# 4    [\n{\n"semantic_unit": "This section discusses...
# ..                                                 ...
# 549  [\n{\n"semantic_unit": "The patient is inquiri...
# 550  [\n{\n"semantic_unit": "The text presents a se...
# 551  [\n  {\n    "semantic_unit": "The text poses q...
# 552  [\n{\n"semantic_unit": "The patient is inquiri...
# 553  [\n{\n"semantic_unit": "A clinical trial is a ...
#
#                            is_valid
# 0    A valid decomposition response
# 1    A valid decomposition response
# 2    A valid decomposition response
# 3    A valid decomposition response
# 4    A valid decomposition response
# ..                              ...
# 549  A valid decomposition response
# 550  A valid decomposition response
# 551  A valid decomposition response
# 552  A valid decomposition response
# 553  A valid decomposition response
#
# [554 rows x 4 columns]

# %%
novel_responses
# Out:
#       index                                           response  \
# 0         0  ```json\n[\n  {\n    "semantic_unit": "This do...
# 1         1  [\n{\n"semantic_unit": "In December 1881, Augu...
# 2         2  [\n{\n"semantic_unit": "The inhabitants of Yuc...
# 3         3  [\n{\n"semantic_unit": "The author describes v...
# 4         4  ```json\n[\n  {\n    "semantic_unit": "Aborigi...
# ...     ...                                                ...
# 2624   2624  [\n{\n"semantic_unit": "The exact origin of th...
# 2625   2625  ```json\n[\n  {\n    "semantic_unit": "Upon ro...
# 2626   2626  [\n{\n"semantic_unit": "The narrator and compa...
# 2627   2627  [\n{\n"semantic_unit": "The author describes a...
# 2628   2628  [\n{\n"semantic_unit": "The text expresses a w...
#
#                                        cleaned_response  \
# 0     [\n  {\n    "semantic_unit": "This document wa...
# 1     [\n{\n"semantic_unit": "In December 1881, Augu...
# 2     [\n{\n"semantic_unit": "The inhabitants of Yuc...
# 3     [\n{\n"semantic_unit": "The author describes v...
# 4     [\n  {\n    "semantic_unit": "Aborigines tell ...
# ...                                                 ...
# 2624  [\n{\n"semantic_unit": "The exact origin of th...
# 2625  [\n  {\n    "semantic_unit": "Upon rounding a ...
# 2626  [\n{\n"semantic_unit": "The narrator and compa...
# 2627  [\n{\n"semantic_unit": "The author describes a...
# 2628  [\n{\n"semantic_unit": "The text expresses a w...
#
#                             is_valid
# 0     A valid decomposition response
# 1     A valid decomposition response
# 2     A valid decomposition response
# 3     A valid decomposition response
# 4     A valid decomposition response
# ...                              ...
# 2624  A valid decomposition response
# 2625  A valid decomposition response
# 2626  A valid decomposition response
# 2627  A valid decomposition response
# 2628  A valid decomposition response
#
# [2629 rows x 4 columns]

# %%
import sys
sys.path.append(root_path)
from graphs.Node import Node

# %%
import re
def entities_in_relationship(rel, entities):
    rel_text = rel.content.lower()
    found = []
    for e in entities:
        pattern = r'\b' + re.escape(e.content.lower()) + r'\b'
        if re.search(pattern, rel_text):
            found.append(e)
    return found

# %%
import json
from tqdm import tqdm
def build_nodes(df, source_name):
    nodes = dict()
    entity_nodes = dict()
    for idx in tqdm(range(len(df))):
        row = df.iloc[idx]
        response = row["cleaned_response"]
        response = json.loads(response)
        for unit_idx,unit in enumerate(response):
            #data
            semantic_unit = unit["semantic_unit"]
            entities = unit["entities"]
            relationships = unit["relationships"]

            #ids
            source_id = f"{source_name}-{idx}"
            semantic_id = f"{source_id}-S-{unit_idx}"
            #entities_ids = [f"{semantic_id}-N-{e_idx}" for e_idx in range(len(entities))]
            relationships_ids = [f"{semantic_id}-R-{r_idx}" for r_idx in range(len(relationships))]

            #create semantic node
            semantic_node = Node(
                id=semantic_id,
                node_type = "S",
                source = source_id,
                content = semantic_unit
            )

            #create entity nodes
            current_entity_nodes = []
            for e_idx, entity in enumerate(entities):
                if entity not in entity_nodes:
                    entity_node = Node(
                        id = f"{source_name}-N-{len(entity_nodes)}",
                        node_type = "N",
                        source = "",
                        content = entity
                    )
                    entity_nodes[entity] = entity_node
                else:
                    entity_node = entity_nodes[entity]
                current_entity_nodes.append(entity_node)

            #create relationship nodes
            relationship_nodes = []
            for r_idx, relationship in enumerate(relationships):
                relationship_node = Node(
                    id = relationships_ids[r_idx],
                    node_type = "R",
                    source = source_id,
                    content = relationship
                )
                relationship_nodes.append(relationship_node)

            #link nodes
            for entity_node in current_entity_nodes:
                semantic_node.link(entity_node)
                entity_node.link(semantic_node)
            
            for relationship_node in relationship_nodes:
                ents = entities_in_relationship(relationship_node, current_entity_nodes)
                for ent in ents:
                    relationship_node.link(ent)
                    ent.link(relationship_node)
            
            current_nodes = [semantic_node] + relationship_nodes
            for n in current_nodes:
                nodes[n.id] = n
    nodes.update({v.id: v for v in entity_nodes.values()})
    entities_dict = {k: v.id for k, v in entity_nodes.items()}
    return nodes, entities_dict

# %%
medical_nodes, medical_entities = build_nodes(medical_responses, "medical")
# Out:
# 100%|██████████| 554/554 [00:01<00:00, 432.71it/s]

# %%
novel_nodes, novel_entities = build_nodes(novel_responses, "novel")
# Out:
# 100%|██████████| 2629/2629 [00:04<00:00, 611.68it/s]

# %%
import pickle
with open(f"{root_path}/graphs/data/G1_medical_primary_graph.pkl", "wb") as f:
    pickle.dump(medical_nodes, f)
with open(f"{root_path}/graphs/data/medical_entities.pkl", "wb") as f:
    pickle.dump(medical_entities, f)
with open(f"{root_path}/graphs/data/G1_novel_primary_graph.pkl", "wb") as f:
    pickle.dump(novel_nodes, f)
with open(f"{root_path}/graphs/data/novel_entities.pkl", "wb") as f:
    pickle.dump(novel_entities, f)

# %%
with open(f"{root_path}/graphs/data/G1_medical_primary_graph.pkl", "rb") as f:
    medical_nodes = pickle.load(f)
with open(f"{root_path}/graphs/data/medical_entities.pkl", "rb") as f:
    medical_entities = pickle.load(f)

with open(f"{root_path}/graphs/data/G1_novel_primary_graph.pkl", "rb") as f:
    novel_nodes = pickle.load(f)
with open(f"{root_path}/graphs/data/novel_entities.pkl", "rb") as f:
    novel_entities = pickle.load(f)

# %%
def nodes_to_dataframe(nodes):
    data = []
    for node in nodes.values():
        data.append({
            "id": node.id,
            "node_type": node.node_type,
            "source": node.source,
            "content": node.content,
            "edges": node.edges
        })
    return pd.DataFrame(data)

# %%
medical_nodes_df = nodes_to_dataframe(medical_nodes)
medical_nodes_df = medical_nodes_df.sort_values(by=["source", "node_type", "id"]).reset_index(drop=True)
medical_nodes_df
# Out:
#                        id node_type      source  \
# 0             medical-N-0         N
# 1             medical-N-1         N
# 2            medical-N-10         N
# 3           medical-N-100         N
# 4          medical-N-1000         N
# ...                   ...       ...         ...
# 31436  medical-99-S-3-R-6         R  medical-99
# 31437      medical-99-S-0         S  medical-99
# 31438      medical-99-S-1         S  medical-99
# 31439      medical-99-S-2         S  medical-99
# 31440      medical-99-S-3         S  medical-99
#
#                                                  content  \
# 0                                 BASAL CELL SKIN CANCER
# 1                             BASAL CELL CARCINOMA (BCC)
# 2                                                   ARMS
# 3                                             METABOLISM
# 4                        EARLY OR LOCALLY ADVANCED NSCLC
# ...                                                  ...
# 31436  HIGHER LEVELS of CREATININE, mean the, KIDNEYS...
# 31437  Gathering family health history, including spe...
# 31438  Blood tests are performed to detect disease an...
# 31439  CBC measurements of particular attention inclu...
# 31440  A Comprehensive Metabolic Panel (CMP) assesses...
#
#                                                    edges
# 0      {'medical-0-S-0': 1, 'medical-0-S-0-R-0': 1, '...
# 1                                   {'medical-0-S-0': 1}
# 2      {'medical-0-S-1': 1, 'medical-0-S-1-R-5': 1, '...
# 3      {'medical-5-S-0': 1, 'medical-5-S-0-R-6': 1, '...
# 4      {'medical-49-S-3': 1, 'medical-49-S-3-R-5': 1,...
# ...                                                  ...
# 31436          {'medical-N-262': 1, 'medical-N-1880': 1}
# 31437  {'medical-N-208': 1, 'medical-N-212': 1, 'medi...
# 31438  {'medical-N-174': 1, 'medical-N-321': 1, 'medi...
# 31439  {'medical-N-1878': 1, 'medical-N-1875': 1, 'me...
# 31440  {'medical-N-1858': 1, 'medical-N-1879': 1, 'me...
#
# [31441 rows x 5 columns]

# %%
medical_entities
# Out:
# {'BASAL CELL SKIN CANCER': 'medical-N-0',
#  'BASAL CELL CARCINOMA (BCC)': 'medical-N-1',
#  '3 MILLION CASES': 'medical-N-2',
#  'UNITED STATES': 'medical-N-3',
#  'SURGERY': 'medical-N-4',
#  'BASAL CELLS': 'medical-N-5',
#  'EPIDERMIS': 'medical-N-6',
#  'FACE': 'medical-N-7',
#  'HEAD': 'medical-N-8',
#  'NECK': 'medical-N-9',
#  'ARMS': 'medical-N-10',
#  'LEGS': 'medical-N-11',
#  'TRUNK': 'medical-N-12',
#  'SKIN': 'medical-N-13',
#  'DERMIS': 'medical-N-14',
#  'HYPODERMIS': 'medical-N-15',
#  'SQUAMOUS CELLS': 'medical-N-16',
#  'MELANOCYTES': 'medical-N-17',
#  'FAT': 'medical-N-18',
#  'CONNECTIVE TISSUE': 'medical-N-19',
#  'ULTRAVIOLET (UV) RAYS': 'medical-N-20',
#  'SQUAMOUS CELL SKIN CANCER': 'medical-N-21',
#  'MELANOMA': 'medical-N-22',
#  'NCCN GUIDELINES FOR PATIENTS': 'medical-N-23',
#  'NCCN.ORG/PATIENTGUIDELINES': 'medical-N-24',
#  'NCCN PATIENT GUIDES FOR CANCER APP': 'medical-N-25',
#  'LIGHTER SKIN': 'medical-N-26',
#  'LIGHTER HAIR': 'medical-N-27',
#  'LIGHTER EYES': 'medical-N-28',
#  'FLAT, PALE OR YELLOW AREAS': 'medical-N-29',
#  'RED PATCHES': 'medical-N-30',
#  'SMALL, PINK OR RED, SHINY BUMPS': 'medical-N-31',
#  'OPEN SORES': 'medical-N-32',
#  'DARKER (BROWN AND BLACK) SKIN': 'medical-N-33',
#  'BROWN OR GLOSSY BLACK BUMP': 'medical-N-34',
#  'ROLLED BORDER': 'medical-N-35',
#  'NORMAL MOLE': 'medical-N-36',
#  'NEW, CHANGING, BLEEDING, OR UNUSUAL SKIN GROWTHS': 'medical-N-37',
#  'SKIN CANCER': 'medical-N-38',
#  'UV RADIATION': 'medical-N-39',
#  'SUN': 'medical-N-40',
#  'TANNING BEDS': 'medical-N-41',
#  'DNA': 'medical-N-42',
#  'BASAL SKIN CELLS': 'medical-N-43',
#  'RISK FACTORS': 'medical-N-44',
#  'CANCER': 'medical-N-45',
#  'FAIR SKIN': 'medical-N-46',
#  'RED HAIR': 'medical-N-47',
#  'BLOND HAIR': 'medical-N-48',
#  'LIGHT EYE COLOR': 'medical-N-49',
#  'MELANIN': 'medical-N-50',
#  'SKIN PIGMENT': 'medical-N-51',
#  'UV RAYS': 'medical-N-52',
#  'AGE': 'medical-N-53',
#  'SUN EXPOSURE': 'medical-N-54',
#  'YOUNGER PEOPLE': 'medical-N-55',
#  'HISTORY OF SKIN CANCER': 'medical-N-56',
#  'RADIATION THERAPY': 'medical-N-57',
#  'YOUNG AGE': 'medical-N-58',
#  'IMMUNE SUPPRESSION': 'medical-N-59',
#  'WEAKENED IMMUNE SYSTEMS': 'medical-N-60',
#  'ORGAN TRANSPLANTS': 'medical-N-61',
#  'AUTOIMMUNE DISEASES': 'medical-N-62',
#  'TREATMENT': 'medical-N-63',
#  'SYSTEMIC THERAPY': 'medical-N-64',
#  'SKIN EXAMS': 'medical-N-65',
#  'DOCTOR': 'medical-N-66',
#  'PREVENTION': 'medical-N-67',
#  'RECURRENCE': 'medical-N-68',
#  'CHAPTER 3': 'medical-N-69',
#  'CHAPTER 4': 'medical-N-70',
#  'PATIENTS': 'medical-N-71',
#  'CARE': 'medical-N-72',
#  'QUESTIONS': 'medical-N-73',
#  'SHARED DECISIONS': 'medical-N-74',
#  'CARE TEAM': 'medical-N-75',
#  'LYMPH NODES': 'medical-N-76',
#  'CHAPTER 3: TYPES OF TREATMENT': 'medical-N-77',
#  'CHAPTER 4: TREATMENT BY RISK AND RECURRENCE': 'medical-N-78',
#  'PROVIDERS': 'medical-N-79',
#  'CANCER CARE RECOMMENDATIONS': 'medical-N-80',
#  'EXPERTS': 'medical-N-81',
#  'LATEST RESEARCH': 'medical-N-82',
#  'PRACTICES AT LEADING CANCER CENTERS': 'medical-N-83',
#  'TREATMENT PLANNING': 'medical-N-84',
#  'TESTING': 'medical-N-85',
#  'CHAPTER': 'medical-N-86',
#  'CONCERNING LESION': 'medical-N-87',
#  'GENERAL HEALTH TESTS': 'medical-N-88',
#  'BIOPSY': 'medical-N-89',
#  'IMAGING': 'medical-N-90',
#  'ACCURATE TESTING': 'medical-N-91',
#  'YOUR DOCTOR': 'medical-N-92',
#  'ADRENAL GLANDS': 'medical-N-93',
#  'ENDOCRINE SYSTEM': 'medical-N-94',
#  'HORMONES': 'medical-N-95',
#  'ADRENAL CORTEX': 'medical-N-96',
#  'CORTISOL': 'medical-N-97',
#  'ALDOSTERONE': 'medical-N-98',
#  'DEHYDROEPIANDROSTERONE (DHEA)': 'medical-N-99',
#  'METABOLISM': 'medical-N-100',
#  'BLOOD PRESSURE': 'medical-N-101',
#  'BODY FEATURES': 'medical-N-102',
#  'ADRENAL MEDULLA': 'medical-N-103',
#  'EPINEPHRINE': 'medical-N-104',
#  'NOREPINEPHRINE': 'medical-N-105',
#  'DOPAMINE': 'medical-N-106',
#  'STRESS': 'medical-N-107',
#  'ADRENALINE': 'medical-N-108',
#  'ADRENAL TUMORS': 'medical-N-109',
#  'SYMPTOMS': 'medical-N-110',
#  'MALIGNANT ADRENAL TUMORS': 'medical-N-111',
#  'GENETIC CONDITIONS': 'medical-N-112',
#  'BENIGN': 'medical-N-113',
#  'MALIGNANT': 'medical-N-114',
#  'ADENOMA': 'medical-N-115',
#  'STRESS HORMONE': 'medical-N-116',
#  'CUSHING SYNDROME': 'medical-N-117',
#  'ADRENOCORTICAL CARCINOMA (ACC)': 'medical-N-118',
#  'ADRENAL GLAND CANCER': 'medical-N-119',
#  'NEUROBLASTOMA': 'medical-N-120',
#  'CHILDREN AGES 5 AND UNDER': 'medical-N-121',
#  'BONES': 'medical-N-122',
#  'PHEOCHROMOCYTOMA': 'medical-N-123',
#  'HIGH BLOOD PRESSURE': 'medical-N-124',
#  'HEADACHE': 'medical-N-125',
#  'RAPID HEARTBEAT': 'medical-N-126',
#  'SWEATING': 'medical-N-127',
#  'ADRENAL CANCER': 'medical-N-128',
#  'ADULTS IN THEIR 40S AND 50S': 'medical-N-129',
#  'CURE': 'medical-N-130',
#  'WEIGHT GAIN': 'medical-N-131',
#  'MUSCLE WEAKNESS': 'medical-N-132',
#  'PINK OR PURPLE STRETCH MARKS': 'medical-N-133',
#  'HORMONAL CHANGES': 'medical-N-134',
#  'EXCESS FACIAL HAIR': 'medical-N-135',
#  'HAIR LOSS ON THE HEAD': 'medical-N-136',
#  'IRREGULAR PERIODS': 'medical-N-137',
#  'ENLARGED BREAST TISSUE': 'medical-N-138',
#  'SHRINKING TESTICLES': 'medical-N-139',
#  'NAUSEA': 'medical-N-140',
#  'VOMITING': 'medical-N-141',
#  'ABDOMINAL BLOATING': 'medical-N-142',
#  'BACK PAIN': 'medical-N-143',
#  'FEVER': 'medical-N-144',
#  'LOSS OF APPETITE': 'medical-N-145',
#  'LOSS OF WEIGHT WITHOUT TRYING': 'medical-N-146',
#  'GENETIC (HEREDITARY) CONDITIONS': 'medical-N-147',
#  'BIOLOGICAL PARENT': 'medical-N-148',
#  'CHILD': 'medical-N-149',
#  'GENES': 'medical-N-150',
#  'BECKWITH-WIEDEMANN SYNDROME': 'medical-N-151',
#  'CARNEY COMPLEX': 'medical-N-152',
#  'FAMILIAL ADENOMATOUS POLYPOSIS (FAP)': 'medical-N-153',
#  'HEREDITARY PARAGANGLIOMAPHEOCHROMOCYTOMA (PGL/PCC) SYNDROME': 'medical-N-154',
#  'LI-FRAUMENI SYNDROME': 'medical-N-155',
#  'LYNCH SYNDROME': 'medical-N-156',
#  'MULTIPLE ENDOCRINE NEOPLASIA TYPE 1 (MEN 1)': 'medical-N-157',
#  'MULTIPLE ENDOCRINE NEOPLASIA TYPE 2 (MEN 2)': 'medical-N-158',
#  'NEUROFIBROMATOSIS TYPE 1 (NF1)': 'medical-N-159',
#  'VON HIPPEL-LINDAU SYNDROME (VHL)': 'medical-N-160',
#  'KIDNEY TUMOR': 'medical-N-161',
#  'BLOODSTREAM': 'medical-N-162',
#  'ORGANS': 'medical-N-163',
#  'CELLS': 'medical-N-164',
#  'NCCN GUIDELINES FOR PATIENTS: KIDNEY CANCER': 'medical-N-165',
#  'TISSUES': 'medical-N-166',
#  'TUMORS': 'medical-N-167',
#  'ADRENOCORTICAL CANCER (ACC)': 'medical-N-168',
#  'NEARBY ORGANS': 'medical-N-169',
#  'HEREDITARY CONDITIONS': 'medical-N-170',
#  'TEST RESULTS': 'medical-N-171',
#  'TREATMENT PLAN': 'medical-N-172',
#  'DOCTOR VISITS': 'medical-N-173',
#  'BLOOD TESTS': 'medical-N-174',
#  'IMAGING RESULTS': 'medical-N-175',
#  'INSURANCE FORMS': 'medical-N-176',
#  'MEDICAL RECORDS': 'medical-N-177',
#  'APPOINTMENTS': 'medical-N-178',
#  'REPORTS': 'medical-N-179',
#  'SPECIFIC DISEASE': 'medical-N-180',
#  'COMPUTER': 'medical-N-181',
#  'CONTACT INFORMATION': 'medical-N-182',
#  'PHONE': 'medical-N-183',
#  'PRIMARY CARE PHYSICIAN': 'medical-N-184',
#  'MEDICAL BINDER': 'medical-N-185',
#  'NOTEBOOK': 'medical-N-186',
#  'RECORDS': 'medical-N-187',
#  'SECOND OPINION': 'medical-N-188',
#  'ZIPPER POCKET': 'medical-N-189',
#  'PEN': 'medical-N-190',
#  'CALENDAR': 'medical-N-191',
#  'INSURANCE CARDS': 'medical-N-192',
#  'FOLDERS': 'medical-N-193',
#  'ONLINE PATIENT PORTALS': 'medical-N-194',
#  'BINDER': 'medical-N-195',
#  'NOTES': 'medical-N-196',
#  'MEDICAL HISTORY': 'medical-N-197',
#  'HEALTH ISSUES': 'medical-N-198',
#  'TREATMENTS': 'medical-N-199',
#  'ILLNESS': 'medical-N-200',
#  'INJURY': 'medical-N-201',
#  'MEDICINES': 'medical-N-202',
#  'OVER-THE-COUNTER MEDICINES': 'medical-N-203',
#  'HERBALS': 'medical-N-204',
#  'SUPPLEMENTS': 'medical-N-205',
#  'CANCERS': 'medical-N-206',
#  'DISEASES': 'medical-N-207',
#  'FAMILY MEMBERS': 'medical-N-208',
#  'HEALTH HISTORY': 'medical-N-209',
#  'FAMILY HISTORY': 'medical-N-210',
#  'BLOOD RELATIVES': 'medical-N-211',
#  'HEART DISEASE': 'medical-N-212',
#  'DIABETES': 'medical-N-213',
#  'OTHER DISEASES': 'medical-N-214',
#  'FAMILIES': 'medical-N-215',
#  'DIAGNOSED': 'medical-N-216',
#  'UNDERARM': 'medical-N-217',
#  'GROIN': 'medical-N-218',
#  'LUMPS': 'medical-N-219',
#  'PAIN': 'medical-N-220',
#  'NCCN GUIDELINES FOR PATIENTS® ADRENAL TUMORS, 2022': 'medical-N-221',
#  'FAMILY HEALTH HISTORY': 'medical-N-222',
#  'PARENT': 'medical-N-223',
#  'DECEASED RELATIVES': 'medical-N-224',
#  'CAUSE OF DEATH': 'medical-N-225',
#  'PARENTS': 'medical-N-226',
#  'SIBLINGS': 'medical-N-227',
#  'CHILDREN': 'medical-N-228',
#  'HALF-SIBLINGS': 'medical-N-229',
#  'AUNTS AND UNCLES': 'medical-N-230',
#  'NIECE AND NEPHEWS': 'medical-N-231',
#  'GRANDPARENTS': 'medical-N-232',
#  'GRANDCHILDREN': 'medical-N-233',
#  'CHRONIC DISEASES': 'medical-N-234',
#  'HEALTH CONDITIONS': 'medical-N-235',
#  'HIGH CHOLESTEROL': 'medical-N-236',
#  'STROKE': 'medical-N-237',
#  "FAMILY'S ANCESTRY": 'medical-N-238',
#  'COUNTRIES': 'medical-N-239',
#  'ANCESTORS': 'medical-N-240',
#  'IMAGING TESTS': 'medical-N-241',
#  'BODY': 'medical-N-242',
#  'RADIOLOGIST': 'medical-N-243',
#  'TEST IMAGES': 'medical-N-244',
#  'REPORT': 'medical-N-245',
#  'CT SCAN': 'medical-N-246',
#  'X-RAYS': 'medical-N-247',
#  'COMPUTER TECHNOLOGY': 'medical-N-248',
#  'THREE-DIMENSIONAL PICTURE': 'medical-N-249',
#  'BODY PART': 'medical-N-250',
#  'ANGLES': 'medical-N-251',
#  'CONTRAST': 'medical-N-252',
#  'VEIN': 'medical-N-253',
#  'URINE': 'medical-N-254',
#  'MRI': 'medical-N-255',
#  'ALLERGIC REACTIONS': 'medical-N-256',
#  'DIPHENHYDRAMINE': 'medical-N-257',
#  'BENADRYL': 'medical-N-258',
#  'PREDNISONE': 'medical-N-259',
#  'STEROIDS': 'medical-N-260',
#  'ALLERGIES': 'medical-N-261',
#  'KIDNEYS': 'medical-N-262',
#  'MRI SCAN': 'medical-N-263',
#  'RADIO WAVES': 'medical-N-264',
#  'POWERFUL MAGNETS': 'medical-N-265',
#  'TREATMENT RESULTS': 'medical-N-266',
#  'PET SCAN': 'medical-N-267',
#  'RADIOACTIVE DRUG': 'medical-N-268',
#  'TRACER': 'medical-N-269',
#  'CANCER CELLS': 'medical-N-270',
#  'CT': 'medical-N-271',
#  'PET/CT': 'medical-N-272',
#  'PET/MRI': 'medical-N-273',
#  'FDG-PET': 'medical-N-274',
#  'SSTR': 'medical-N-275',
#  'PET': 'medical-N-276',
#  'RADIOACTIVE TYPE OF SUGAR': 'medical-N-277',
#  '18-FLUORODEOXYGLUCOSE': 'medical-N-278',
#  'NORMAL CELLS': 'medical-N-279',
#  'NEUROENDOCRINE TUMORS': 'medical-N-280',
#  'PET SCANS': 'medical-N-281',
#  'SSTR-PET': 'medical-N-282',
#  'FDG-PET/CT SCAN': 'medical-N-283',
#  'RADIOACTIVE TYPE OF SUGAR (18-FLUORODEOXYGLUCOSE)': 'medical-N-284',
#  'ACTIVE CANCER CELLS': 'medical-N-285',
#  'SOMATOSTATIN': 'medical-N-286',
#  'SSTRS': 'medical-N-287',
#  'CELL TYPES': 'medical-N-288',
#  'HORMONE SECRETION': 'medical-N-289',
#  'CERTAIN TREATMENTS': 'medical-N-290',
#  'BIOCHEMICAL TESTS': 'medical-N-291',
#  'SUBSTANCES LIKE HORMONES': 'medical-N-292',
#  'BLOOD': 'medical-N-293',
#  'SALIVA': 'medical-N-294',
#  'ADRENAL TUMOR': 'medical-N-295',
#  'TOO MUCH OF A HORMONE': 'medical-N-296',
#  'SYNDROMES CAUSED BY A TUMOR': 'medical-N-297',
#  'GUIDE 1 BIOCHEMICAL TESTS': 'medical-N-298',
#  'BASAL CELL CARCINOMA': 'medical-N-299',
#  'NONMELANOMA SKIN CANCERS': 'medical-N-300',
#  'KERATINOCYTE CARCINOMAS': 'medical-N-301',
#  'SQUAMOUS CELL CARCINOMA': 'medical-N-302',
#  'LUNGS': 'medical-N-303',
#  'THYROID': 'medical-N-304',
#  'ESOPHAGUS': 'medical-N-305',
#  'CUTANEOUS SQUAMOUS CELL CARCINOMA': 'medical-N-306',
#  'SQUAMOUS CELL SKIN CANCERS': 'medical-N-307',
#  'SCALY PATCHES': 'medical-N-308',
#  'SOLID AND MISSAPEN GROWTHS': 'medical-N-309',
#  'CUTANEOUS SQUAMOUS CELL CARCINOMA (CSCC)': 'medical-N-310',
#  'INVADERS (SUCH AS MICROBES)': 'medical-N-311',
#  'BODY TEMPERATURE': 'medical-N-312',
#  'TOUCH, HEAT, AND COLD': 'medical-N-313',
#  '3 LAYERS': 'medical-N-314',
#  'HYPODERMIS (SUBCUTIS)': 'medical-N-315',
#  'SKIN CANCERS': 'medical-N-316',
#  '3 MAIN TYPES OF CELLS': 'medical-N-317',
#  "SKIN'S SURFACE TISSUE": 'medical-N-318',
#  'BASAL CELL LAYER': 'medical-N-319',
#  'RISK FACTOR': 'medical-N-320',
#  'DISEASE': 'medical-N-321',
#  'SMOKING CIGARETTES': 'medical-N-322',
#  'LUNG CANCER': 'medical-N-323',
#  'SUNLIGHT': 'medical-N-324',
#  'OUTDOOR TANNING': 'medical-N-325',
#  'PEOPLE WHO SUNBURN EASILY': 'medical-N-326',
#  'LIGHT SKIN': 'medical-N-327',
#  'LIGHT HAIR': 'medical-N-328',
#  'LIGHT EYES': 'medical-N-329',
#  'PEOPLE WHO WORK OUTDOORS': 'medical-N-330',
#  'INDOOR TANNING': 'medical-N-331',
#  'ENVIRONMENTAL TOXINS': 'medical-N-332',
#  'TOBACCO SMOKE': 'medical-N-333',
#  'EXHAUST FROM CARS OR OTHER VEHICLES': 'medical-N-334',
#  'ARSENIC': 'medical-N-335',
#  'SOIL': 'medical-N-336',
#  'WATER': 'medical-N-337',
#  'AIR': 'medical-N-338',
#  'SKIN DAMAGE': 'medical-N-339',
#  'SCARS': 'medical-N-340',
#  'CHRONIC WOUNDS': 'medical-N-341',
#  'ULCERS': 'medical-N-342',
#  'BURNS': 'medical-N-343',
#  'MARJOLIN’S ULCER': 'medical-N-344',
#  'INDOOR TANNING MACHINES': 'medical-N-345',
#  'BOOTHS': 'medical-N-346',
#  'BEDS': 'medical-N-347',
#  'CHRONIC (NONHEALING) WOUNDS': 'medical-N-348',
#  'SORES': 'medical-N-349',
#  'ACTINIC KERATOSES': 'medical-N-350',
#  'SCALY OR ROUGH SKIN': 'medical-N-351',
#  'LESIONS': 'medical-N-352',
#  'WARTS': 'medical-N-353',
#  'DERMATOLOGIST': 'medical-N-354',
#  'GENETIC SYNDROMES': 'medical-N-355',
#  'XERODERMA PIGMENTOSUM (XP)': 'medical-N-356',
#  'RECESSIVE DYSTROPHIC EPIDERMOLYSIS BULLOSA (RDEB)': 'medical-N-357',
#  'SKIN DISORDER': 'medical-N-358',
#  'TRAUMA': 'medical-N-359',
#  'BLISTERS': 'medical-N-360',
#  'NCCN': 'medical-N-361',
#  'CANCER CENTER': 'medical-N-362',
#  'CSCC PREVENTION AND TREATMENT': 'medical-N-363',
#  'GENETIC RISK': 'medical-N-364',
#  'CANCER GENETICS': 'medical-N-365',
#  'GENETIC COUNSELOR': 'medical-N-366',
#  'MEDICAL GENETICIST': 'medical-N-367',
#  'ENDOCRINOLOGIST': 'medical-N-368',
#  'ONCOLOGIST': 'medical-N-369',
#  'SURGEON': 'medical-N-370',
#  'ONCOLOGY NURSE': 'medical-N-371',
#  'WEAKENED IMMUNE SYSTEM': 'medical-N-372',
#  'VIRUSES': 'medical-N-373',
#  'BACTERIA': 'medical-N-374',
#  'FUNGI': 'medical-N-375',
#  'GENETIC RISK OF SKIN CANCER': 'medical-N-376',
#  'COUNSELING': 'medical-N-377',
#  'ORGAN TRANSPLANTATION': 'medical-N-378',
#  'IMMUNOSUPPRESSANTS': 'medical-N-379',
#  'LYMPHOMA': 'medical-N-380',
#  'CHRONIC LYMPHOCYTIC LEUKEMIA': 'medical-N-381',
#  'HUMAN IMMUNODEFICIENCY VIRUS (HIV)': 'medical-N-382',
#  'AIDS': 'medical-N-383',
#  'SKIN CANCER SCREENING': 'medical-N-384',
#  'DIAGNOSIS': 'medical-N-385',
#  'ABNORMAL-LOOKING SKIN': 'medical-N-386',
#  'LESION': 'medical-N-387',
#  'FULL HEALTH HISTORY': 'medical-N-388',
#  'EXAMINATION OF THE LESION(S)': 'medical-N-389',
#  'SKIN BIOPSY': 'medical-N-390',
#  'SAMPLE OF THE LESION': 'medical-N-391',
#  'IMAGING SCANS': 'medical-N-392',
#  'PATHOLOGIST': 'medical-N-393',
#  'OTHER PARTS OF THE BODY': 'medical-N-394',
#  'LAB': 'medical-N-395',
#  'MICROSCOPE': 'medical-N-396',
#  'SCAR': 'medical-N-397',
#  'SUSPECTED AREA': 'medical-N-398',
#  'ACCURATE DIAGNOSIS': 'medical-N-399',
#  'SKIN BIOPSIES': 'medical-N-400',
#  'LOCAL ANESTHETIC': 'medical-N-401',
#  'NUMBING MEDICINE': 'medical-N-402',
#  'NEEDLE': 'medical-N-403',
#  'PRICK': 'medical-N-404',
#  'STINGING': 'medical-N-405',
#  'SKIN SHAVE BIOPSY': 'medical-N-406',
#  'SKIN SURFACE': 'medical-N-407',
#  'FLAT SKIN LESIONS': 'medical-N-408',
#  'RAZOR': 'medical-N-409',
#  'SKIN PUNCH BIOPSY': 'medical-N-410',
#  'PIECE OF SKIN': 'medical-N-411',
#  'HAND-HELD TOOL': 'medical-N-412',
#  'STITCHES': 'medical-N-413',
#  'OPENING IN THE SKIN': 'medical-N-414',
#  'EXCISION BIOPSY': 'medical-N-415',
#  'TYPE OF CANCER': 'medical-N-416',
#  'TEST TYPES': 'medical-N-417',
#  'PATHOLOGY': 'medical-N-418',
#  'RADIOLOGY': 'medical-N-419',
#  'GENETICS': 'medical-N-420',
#  'PROCEDURES': 'medical-N-421',
#  "DOCTOR'S OFFICE": 'medical-N-422',
#  'HOSPITAL': 'medical-N-423',
#  'BIOPSY INCISION': 'medical-N-424',
#  'SUSPICIOUS-LOOKING LESION': 'medical-N-425',
#  'BONE': 'medical-N-426',
#  'NERVES': 'medical-N-427',
#  'SURROUNDING DEEP SOFT TISSUE': 'medical-N-428',
#  'COMPUTED TOMOGRAPHY (CT) SCAN': 'medical-N-429',
#  'X-RAY MACHINE': 'medical-N-430',
#  '3-DIMENSIONAL (3-D) VIEWS': 'medical-N-431',
#  'MAGNET': 'medical-N-432',
#  'CONTRAST DYE': 'medical-N-433',
#  'ALLERGY': 'medical-N-434',
#  'CONDITION': 'medical-N-435',
#  'HARMFUL REACTION': 'medical-N-436',
#  'POSITRON EMISSION TOMOGRAPHY (PET) SCAN': 'medical-N-437',
#  'IV': 'medical-N-438',
#  'ELBOW': 'medical-N-439',
#  'INSIDE OF YOUR ELBOW': 'medical-N-440',
#  'NON-CANCER CELLS': 'medical-N-441',
#  'RADIOACTIVE PART OF THE TRACER': 'medical-N-442',
#  'BRIGHT SPOTS': 'medical-N-443',
#  'PET/CT SCAN': 'medical-N-444',
#  'LIGHTER-SKINNED PEOPLE': 'medical-N-445',
#  'AREAS OF THE BODY EXPOSED TO SUN': 'medical-N-446',
#  'HEAD AND NECK': 'medical-N-447',
#  'DISTANT AREAS OF THE BODY': 'medical-N-448',
#  'AREA WHERE IT FIRST FORMS': 'medical-N-449',
#  'SEVERE SKIN DAMAGE': 'medical-N-450',
#  'DEATH': 'medical-N-451',
#  'MOST PEOPLE': 'medical-N-452',
#  'CSCC': 'medical-N-453',
#  'HEAD-TO-TOE SKIN EXAM': 'medical-N-454',
#  'LYMPH': 'medical-N-455',
#  'LYMPHATIC FLUID': 'medical-N-456',
#  'IMMUNE SYSTEM': 'medical-N-457',
#  'LYMPHOCYTES': 'medical-N-458',
#  'INFECTION': 'medical-N-459',
#  'NODAL DISEASE': 'medical-N-460',
#  'NEEDLE BIOPSY': 'medical-N-461',
#  'WHITE BLOOD CELLS': 'medical-N-462',
#  'LYMPH NODE': 'medical-N-463',
#  'REGIONAL': 'medical-N-464',
#  'PART 4': 'medical-N-465',
#  'REGIONAL CSCC': 'medical-N-466',
#  'SUNBURNS': 'medical-N-467',
#  'SPENDING TOO MUCH TIME IN THE SUN': 'medical-N-468',
#  'ACTINIC KERATOSIS': 'medical-N-469',
#  'CERTAIN GENETIC SYNDROMES': 'medical-N-470',
#  'OLD WOUNDS': 'medical-N-471',
#  'TREAT': 'medical-N-472',
#  'TESTING FOR CSCC': 'medical-N-473',
#  'EXAMINATION OF ANY LESIONS': 'medical-N-474',
#  'LYMPH FLUID': 'medical-N-475',
#  'LYMPH NODE BIOPSY': 'medical-N-476',
#  'SUPERFICIAL TREATMENTS': 'medical-N-477',
#  'CLINICAL TRIALS': 'medical-N-478',
#  'PERSONAL PREFERENCES': 'medical-N-479',
#  'DERMATOLOGISTS': 'medical-N-480',
#  'SKIN CONDITIONS': 'medical-N-481',
#  'MOHS SURGEONS': 'medical-N-482',
#  'MOHS SURGERY': 'medical-N-483',
#  'TUMOR': 'medical-N-484',
#  'SURGICAL ONCOLOGISTS': 'medical-N-485',
#  'CANCEROUS TUMORS': 'medical-N-486',
#  'MEDICAL ONCOLOGISTS': 'medical-N-487',
#  'CANCER-TREATMENT DRUGS': 'medical-N-488',
#  'CHEMOTHERAPY': 'medical-N-489',
#  'PATHOLOGISTS': 'medical-N-490',
#  'TISSUE': 'medical-N-491',
#  'PLASTIC SURGEONS': 'medical-N-492',
#  'BODY PARTS': 'medical-N-493',
#  'WOUND': 'medical-N-494',
#  'GENERAL ANESTHESIA': 'medical-N-495',
#  'CANCEROUS TUMOR': 'medical-N-496',
#  'DEEPER TISSUE': 'medical-N-497',
#  'RADIATION ONCOLOGISTS': 'medical-N-498',
#  'PHARMACISTS': 'medical-N-499',
#  'MEDICINE': 'medical-N-500',
#  'SIDE EFFECTS': 'medical-N-501',
#  'CANCER PATIENTS': 'medical-N-502',
#  'GENETICISTS': 'medical-N-503',
#  'TRAITS': 'medical-N-504',
#  'GENETIC DISORDERS': 'medical-N-505',
#  'PEOPLE': 'medical-N-506',
#  'ONCOLOGY NURSES': 'medical-N-507',
#  'NURSE NAVIGATORS': 'medical-N-508',
#  'TEAM MEMBERS': 'medical-N-509',
#  'LIST OF NAMES': 'medical-N-510',
#  'TOP LAYER OF THE SKIN': 'medical-N-511',
#  'EARLIEST FORM OF SQUAMOUS CELL SKIN CANCER': 'medical-N-512',
#  'BOWEN’S DISEASE': 'medical-N-513',
#  'BOWEN’S LESION': 'medical-N-514',
#  'PHOTODYNAMIC THERAPY (PDT)': 'medical-N-515',
#  'LIGHT-SENSITIVE DRUG': 'medical-N-516',
#  'AREA': 'medical-N-517',
#  'LIGHT': 'medical-N-518',
#  'RED OR BLUE LIGHT': 'medical-N-519',
#  'DOCTOR’S OFFICE': 'medical-N-520',
#  'SHADED OUTDOOR LIGHT': 'medical-N-521',
#  'SIDE EFFECTS OF PDT': 'medical-N-522',
#  'DRUG': 'medical-N-523',
#  'LIGHT EXPOSURE': 'medical-N-524',
#  'ITCTHING AND REDNESS': 'medical-N-525',
#  'RED LIGHT': 'medical-N-526',
#  'BLUE LIGHT': 'medical-N-527',
#  'ITCHING': 'medical-N-528',
#  'BURNING': 'medical-N-529',
#  'CRYOTHERAPY': 'medical-N-530',
#  'BURNING SENSATION': 'medical-N-531',
#  'BLISTER': 'medical-N-532',
#  'SCAB': 'medical-N-533',
#  'SKIN DARKENING': 'medical-N-534',
#  'SKIN LIGHTENING': 'medical-N-535',
#  'TOPICAL THERAPIES': 'medical-N-536',
#  '5-FLUOROURACIL (CARAC, EFUDEX, FLUOROPLEX)': 'medical-N-537',
#  'IMIQUIMOD (ALDARA)': 'medical-N-538',
#  'EARLY CSCC': 'medical-N-539',
#  '5-FU': 'medical-N-540',
#  'CALCIPOTRIENE (SORILUX, DOVONEX)': 'medical-N-541',
#  'VITAMIN D': 'medical-N-542',
#  'ABNORMAL SKIN CELLS': 'medical-N-543',
#  'TIRBANIBULIN (KLISYRI)': 'medical-N-544',
#  'SCALP': 'medical-N-545',
#  'HYPERKERATOSIS': 'medical-N-546',
#  'HYPERKERATOTIC ACTINIC KERATOSES': 'medical-N-547',
#  'TOPICAL TAZAROTENE': 'medical-N-548',
#  'RETINOID': 'medical-N-549',
#  'CURETTAGE': 'medical-N-550',
#  'TOPICAL KERATOLYTICS': 'medical-N-551',
#  'UREA': 'medical-N-552',
#  'LACTIC ACID': 'medical-N-553',
#  'SALICYLIC ACID': 'medical-N-554',
#  'REDNESS': 'medical-N-555',
#  'SUN-DAMAGED SKIN': 'medical-N-556',
#  'EXCISION': 'medical-N-557',
#  'CURETTAGE AND ELECTRODESICCATION (C&E)': 'medical-N-558',
#  'VISIBLE TUMOR': 'medical-N-559',
#  'MEDICAL OFFICE': 'medical-N-560',
#  'LOCAL NUMBING': 'medical-N-561',
#  'ELECTRIC NEEDLE': 'medical-N-562',
#  'WOUND BASE': 'medical-N-563',
#  'BLEEDING': 'medical-N-564',
#  'PERIPHERAL AND DEEP EN FACE MARGIN ASSESSMENT (PDEMA)': 'medical-N-565',
#  'HANDS': 'medical-N-566',
#  'FEET': 'medical-N-567',
#  'SHINS': 'medical-N-568',
#  'GENITAL AREAS': 'medical-N-569',
#  'NORMAL TISSUE': 'medical-N-570',
#  'SURGEONS': 'medical-N-571',
#  'REMOVED TISSUE': 'medical-N-572',
#  'DERMATOLOGIC SURGEON': 'medical-N-573',
#  'SURGICAL SUITE': 'medical-N-574',
#  'DERMATOLOGIC (SKIN) SURGEON': 'medical-N-575',
#  'THIN LAYER OF SURROUNDING TISSUE': 'medical-N-576',
#  'MOHS SURGEON': 'medical-N-577',
#  'AREA OF THE WOUND': 'medical-N-578',
#  'EDGES': 'medical-N-579',
#  'STANDARD SURGICAL EXCISION': 'medical-N-580',
#  'SCALPEL BLADE': 'medical-N-581',
#  'SURGICAL MARGIN': 'medical-N-582',
#  'PDEMA': 'medical-N-583',
#  'HIGH-RISK LOCAL CSCC': 'medical-N-584',
#  'SQUAMOUS CELL SKIN CANCER TUMOR': 'medical-N-585',
#  'LYMPH NODE DISSECTION': 'medical-N-586',
#  'MARGIN': 'medical-N-587',
#  'SENTINEL LYMPH NODE': 'medical-N-588',
#  'PRIMARY TUMOR': 'medical-N-589',
#  'SENTINEL LYMPH NODE BIOPSY (SLNB)': 'medical-N-590',
#  'TISSUE SAMPLES': 'medical-N-591',
#  'CANCER STAGING': 'medical-N-592',
#  'RADIOACTIVE, BLUE-COLORED SUBSTANCE': 'medical-N-593',
#  'WOUNDS': 'medical-N-594',
#  'SECONDARY INTENTION HEALING': 'medical-N-595',
#  'DRESSINGS': 'medical-N-596',
#  'LINEAR CLOSURE': 'medical-N-597',
#  'FUSIFORM': 'medical-N-598',
#  '6 WEEKS': 'medical-N-599',
#  'SKIN GRAFT': 'medical-N-600',
#  'PDEMA/MOHS PROCEDURE': 'medical-N-601',
#  '6 TO 10 WEEKS': 'medical-N-602',
#  'SCAR TREATMENT': 'medical-N-603',
#  'AFTERCARE': 'medical-N-604',
#  'RADIATION THERAPY (RT)': 'medical-N-605',
#  'ELECTRONS': 'medical-N-606',
#  'PHOTONS': 'medical-N-607',
#  'PROTONS': 'medical-N-608',
#  '5 DAILY BRIEF TREATMENTS PER WEEK': 'medical-N-609',
#  '3 TO 7 WEEKS': 'medical-N-610',
#  'RADIATION ONCOLOGIST': 'medical-N-611',
#  'EXTERNAL BEAM RADIATION THERAPY (EBRT)': 'medical-N-612',
#  'BRACHYTHERAPY': 'medical-N-613',
#  'MACHINE': 'medical-N-614',
#  'RESECTION (SURGERY)': 'medical-N-615',
#  'SMALL TUMORS': 'medical-N-616',
#  'RADIATION SOURCE': 'medical-N-617',
#  'SHORT PERIOD OF TIME': 'medical-N-618',
#  'CONNECTIVE TISSUE DISEASES': 'medical-N-619',
#  'LUPUS': 'medical-N-620',
#  'SCLERODERMA': 'medical-N-621',
#  'SAME AREA': 'medical-N-622',
#  'RADIATED AREA': 'medical-N-623',
#  'ADJUVANT THERAPY': 'medical-N-624',
#  'PRIMARY TREATMENT': 'medical-N-625',
#  'RADIATION': 'medical-N-626',
#  'HIGH-RISK TUMORS': 'medical-N-627',
#  'SHORT-TERM SIDE EFFECTS': 'medical-N-628',
#  'SKIN REDNESS': 'medical-N-629',
#  'MILD DISCOMFORT': 'medical-N-630',
#  'FEELING TIRED': 'medical-N-631',
#  'RADIATION COURSE': 'medical-N-632',
#  'LONG-TERM SIDE EFFECTS': 'medical-N-633',
#  'HARDENING OF THE SKIN AND SOFT TISSUE': 'medical-N-634',
#  'TREATMENT AREA': 'medical-N-635',
#  'MILD CHANGE IN SKIN COLOR': 'medical-N-636',
#  'SPIDER VEINS': 'medical-N-637',
#  'NON-HEALING ULCERS': 'medical-N-638',
#  'CATARACTS': 'medical-N-639',
#  'CSCC IN THE EYE AREA': 'medical-N-640',
#  'SECOND CANCER': 'medical-N-641',
#  'TREATED AREA': 'medical-N-642',
#  'YOUNG PATIENTS': 'medical-N-643',
#  'MEDICINE(S)': 'medical-N-644',
#  'CELLS THROUGHOUT THE BODY': 'medical-N-645',
#  'DRUGS': 'medical-N-646',
#  'CISPLATING': 'medical-N-647',
#  'CARBOPLATIN': 'medical-N-648',
#  'TARGETED THERAPY': 'medical-N-649',
#  'RECEPTORS': 'medical-N-650',
#  'EPIDERMAL GROWTH FACTOR RECEPTOR (EGFR)': 'medical-N-651',
#  'EGFR': 'medical-N-652',
#  'PROTEIN': 'medical-N-653',
#  'CETUXIMAB (ERBITUX)': 'medical-N-654',
#  'IMMUNOTHERAPY': 'medical-N-655',
#  'PROGRAMMED DEATH LIGAND 1 (PD-1)': 'medical-N-656',
#  'PD-1 INHIBITORS': 'medical-N-657',
#  'IMMUNE CHECKPOINT INHIBITOR': 'medical-N-658',
#  'CEMIPLIMAB (LIBTAYO)': 'medical-N-659',
#  'PEMBROLIZUMAB (KEYTRUDA)': 'medical-N-660',
#  'PD-1 INHIBITOR': 'medical-N-661',
#  'OTHER CANCERS': 'medical-N-662',
#  'INFERTILITY': 'medical-N-663',
#  'TIREDNESS (FATIGUE)': 'medical-N-664',
#  'NAUSEA AND VOMITING': 'medical-N-665',
#  'LUNG AND BREATHING PROBLEMS': 'medical-N-666',
#  'COUGH': 'medical-N-667',
#  'SHORTNESS OF BREATH': 'medical-N-668',
#  'CHEST PAIN': 'medical-N-669',
#  'MAJOR ORGANS': 'medical-N-670',
#  'LIVER': 'medical-N-671',
#  'HAIR LOSS': 'medical-N-672',
#  'MOUTH SORES': 'medical-N-673',
#  'BODY ACHES': 'medical-N-674',
#  'RASHES AND OTHER SKIN PROBLEMS': 'medical-N-675',
#  'DIARRHEA': 'medical-N-676',
#  'CONSTIPATION': 'medical-N-677',
#  'LOW BLOOD CELL COUNTS': 'medical-N-678',
#  'ABNORMAL BLEEDING': 'medical-N-679',
#  'IMMUNE-RELATED ADVERSE EVENTS (IRAE)': 'medical-N-680',
#  'IMMUNE CHECKPOINT INHIBITORS': 'medical-N-681',
#  'CLINICAL TRIAL': 'medical-N-682',
#  'MEDICAL RESEARCH STUDY': 'medical-N-683',
#  'LABORATORY': 'medical-N-684',
#  'DEVICE': 'medical-N-685',
#  'TREATMENT APPROACH': 'medical-N-686',
#  'U.S. FOOD AND DRUG ADMINISTRATION (FDA)': 'medical-N-687',
#  'STANDARD TREATMENTS': 'medical-N-688',
#  'CANCER CLINICAL TRIALS': 'medical-N-689',
#  'PHASE 1 TRIALS': 'medical-N-690',
#  'DOSE': 'medical-N-691',
#  'SAFETY': 'medical-N-692',
#  'INVESTIGATIONAL DRUG': 'medical-N-693',
#  'PHASE 2 TRIALS': 'medical-N-694',
#  'PHASE 3 TRIALS': 'medical-N-695',
#  'STANDARD TREATMENT': 'medical-N-696',
#  'SPECIFIC TYPE OF CANCER': 'medical-N-697',
#  'PHASE 4 TRIALS': 'medical-N-698',
#  'FDA-APPROVED TREATMENT': 'medical-N-699',
#  'RULES FOR JOINING': 'medical-N-700',
#  'ELIGIBILITY CRITERIA': 'medical-N-701',
#  'CANCER TYPE': 'medical-N-702',
#  'STAGE': 'medical-N-703',
#  'TREATMENT HISTORY': 'medical-N-704',
#  'GENERAL HEALTH': 'medical-N-705',
#  'PARTICIPANTS': 'medical-N-706',
#  'GROUP OF EXPERTS': 'medical-N-707',
#  'RESEARCH TEAM': 'medical-N-708',
#  'STUDY': 'medical-N-709',
#  'PURPOSE': 'medical-N-710',
#  'RISKS': 'medical-N-711',
#  'BENEFITS': 'medical-N-712',
#  'INFORMED CONSENT FORM': 'medical-N-713',
#  'FAMILY': 'medical-N-714',
#  'FRIENDS': 'medical-N-715',
#  'OTHERS YOU TRUST': 'medical-N-716',
#  'TREATMENT OUTSIDE OF THE CLINICAL TRIAL': 'medical-N-717',
#  'TREATMENT OPTIONS': 'medical-N-718',
#  'TREATMENT TEAM': 'medical-N-719',
#  'REQUIREMENTS': 'medical-N-720',
#  'CERTAIN CLINICAL TRIALS': 'medical-N-721',
#  'NEW CLINICAL TRIALS': 'medical-N-722',
#  'MYTHS': 'medical-N-723',
#  'MISCONCEPTIONS': 'medical-N-724',
#  'POSSIBLE BENEFITS': 'medical-N-725',
#  'MANY WITH CANCER': 'medical-N-726',
#  'PLACEBOS': 'medical-N-727',
#  'REAL MEDICINES': 'medical-N-728',
#  'NEW DRUG': 'medical-N-729',
#  'NCI’S CANCER INFORMATION SERVICE (CIS)': 'medical-N-730',
#  '6237': 'medical-N-731',
#  'CANCER.GOV/CONTACT': 'medical-N-732',
#  'STUDY SPONSOR': 'medical-N-733',
#  'RESEARCH-RELATED COSTS': 'medical-N-734',
#  'STUDY DRUG': 'medical-N-735',
#  'INDIRECT COSTS': 'medical-N-736',
#  'TRANSPORTATION': 'medical-N-737',
#  'CHILD CARE': 'medical-N-738',
#  'STANDARD CANCER CARE': 'medical-N-739',
#  'INSURANCE': 'medical-N-740',
#  'CO PAYS': 'medical-N-741',
#  'PHOTODYNAMIC THERAPY': 'medical-N-742',
#  'TOPICAL THERAPY': 'medical-N-743',
#  'PRE-CANCEROUS LESIONS': 'medical-N-744',
#  'TYPES OF SURGERY': 'medical-N-745',
#  'ELECTRODESICCATION': 'medical-N-746',
#  'PDEMA/MOHS SURGERY': 'medical-N-747',
#  'LOCAL CUTANEOUS SQUAMOUS CELL CARCINOMA (CSCC)': 'medical-N-748',
#  'GOAL OF TREATMENT': 'medical-N-749',
#  'REMOVE ALL OF THE CANCER': 'medical-N-750',
#  'SURROUNDING SKIN': 'medical-N-751',
#  'RISK ASSESSMENT': 'medical-N-752',
#  'LOW-RISK': 'medical-N-753',
#  'HIGH-RISK': 'medical-N-754',
#  'VERY HIGH-RISK': 'medical-N-755',
#  'LOCAL DISEASE': 'medical-N-756',
#  'LOCAL RECURRENCE': 'medical-N-757',
#  'METASTASIS': 'medical-N-758',
#  'RISK LEVEL': 'medical-N-759',
#  'LOCATION': 'medical-N-760',
#  'SIZE': 'medical-N-761',
#  'TUMORS ON THE HEAD OR NECK': 'medical-N-762',
#  '2 CENTIMETERS (CM)': 'medical-N-763',
#  '4 CM': 'medical-N-764',
#  'SEX ORGANS': 'medical-N-765',
#  'TUMOR SHAPE': 'medical-N-766',
#  'CLINICAL EXTENT (BORDER)': 'medical-N-767',
#  'LOW RISK': 'medical-N-768',
#  'HIGH RISK': 'medical-N-769',
#  'RECURRENT TUMORS': 'medical-N-770',
#  'BORDER': 'medical-N-771',
#  'TUMOR RETURN AFTER TREATMENT': 'medical-N-772',
#  'AREA OF DAMAGED OR INFLAMED SKIN': 'medical-N-773',
#  'NERVE': 'medical-N-774',
#  'GROUP OF NERVES': 'medical-N-775',
#  'HIGH-RISK CANCER': 'medical-N-776',
#  'VERY HIGH-RISK CANCER': 'medical-N-777',
#  'PERINEURAL INVASION': 'medical-N-778',
#  'LOSS OF FEELING': 'medical-N-779',
#  'LOSS OF MOVEMENT': 'medical-N-780',
#  'DOUBLE VISION': 'medical-N-781',
#  'BLURRED VISION': 'medical-N-782',
#  'TUMOR GRADE': 'medical-N-783',
#  'TUMOR CELLS': 'medical-N-784',
#  'RISK OF SPREADING': 'medical-N-785',
#  'TUMOR TYPE': 'medical-N-786',
#  'SUBTYPE OF CANCER': 'medical-N-787',
#  'RARE SUBTYPES': 'medical-N-788',
#  'FIBROUS TISSUE': 'medical-N-789',
#  'RISK OF THE CANCER RETURNING': 'medical-N-790',
#  'SPREADING TO DISTANT SITES': 'medical-N-791',
#  'BLOOD VESSELS': 'medical-N-792',
#  'LYMPH VESSELS': 'medical-N-793',
#  'MAIN TUMOR': 'medical-N-794',
#  'PARTS OF THE BODY': 'medical-N-795',
#  'LYMPHOVASCULAR INVASION': 'medical-N-796',
#  'FIBROUS OR CONNECTIVE TISSUE': 'medical-N-797',
#  'NEARBY LYMPH NODES': 'medical-N-798',
#  'LONG-TERM CORTICOSTEROID USE': 'medical-N-799',
#  'ORGAN TRANSPLANT': 'medical-N-800',
#  'LOW-RISK CSCC': 'medical-N-801',
#  'SHAVE EXCISION': 'medical-N-802',
#  'LOW-RISK, LOCAL CSCC': 'medical-N-803',
#  'EARLY, SMALL CSCC': 'medical-N-804',
#  'SURFACE OF THE SKIN': 'medical-N-805',
#  'DEEPER THAN EXPECTED AREAS': 'medical-N-806',
#  'CANCEROUS TISSUE': 'medical-N-807',
#  'TESTING AFTER SURGERY': 'medical-N-808',
#  'SURROUNDING TISSUE': 'medical-N-809',
#  'RESECTION WITH PDEMA': 'medical-N-810',
#  'ANOTHER SURGICAL EXCISION': 'medical-N-811',
#  'SMOKERS': 'medical-N-812',
#  'VAPERS': 'medical-N-813',
#  'HELP TO QUIT': 'medical-N-814',
#  'SMOKING': 'medical-N-815',
#  'CANCER TREATMENT': 'medical-N-816',
#  'PART 2': 'medical-N-817',
#  'NICOTINE WITHDRAWAL': 'medical-N-818',
#  'SMOKEFREE.GOV': 'medical-N-819',
#  'BETOBACCOFREE.GOV': 'medical-N-820',
#  'CDC.GOV/TOBACCO': 'medical-N-821',
#  'HIGH-RISK CSCC': 'medical-N-822',
#  'VERY HIGH-RISK CSCC': 'medical-N-823',
#  'LYMPH NODE SPREAD': 'medical-N-824',
#  'HARMLESS DYE': 'medical-N-825',
#  'LOW-LEVEL RADIOACTIVE SOLUTION': 'medical-N-826',
#  'SENTINEL NODES': 'medical-N-827',
#  'DIFFERENT CANCER DOCTORS': 'medical-N-828',
#  'PLATINUM-BASED CHEMOTHERAPY': 'medical-N-829',
#  'CANCER DOCTORS': 'medical-N-830',
#  'NEXT TREATMENT OPTIONS': 'medical-N-831',
#  'VERY HIGH-RISK LOCAL CSCC': 'medical-N-832',
#  'WIDER MARGIN': 'medical-N-833',
#  'NORMAL TISSUE AROUND LESION': 'medical-N-834',
#  'CONCERNING FEATURES': 'medical-N-835',
#  'NEXT STEPS': 'medical-N-836',
#  'CRITICAL HEALTHY ORGANS': 'medical-N-837',
#  'HEALTHY ORGANS': 'medical-N-838',
#  'LOCAL': 'medical-N-839',
#  'MOHS SURGERY OR ANOTHER FORM OF PDEMA': 'medical-N-840',
#  'METASTATIC SQUAMOUS CELL SKIN CANCER': 'medical-N-841',
#  'FINE-NEEDLE ASPIRATION (FNA)': 'medical-N-842',
#  'CORE NEEDLE BIOPSY': 'medical-N-843',
#  'CANCEROUS LESION': 'medical-N-844',
#  'CEMIPLIMAB-RWLC': 'medical-N-845',
#  'LIBTAYO': 'medical-N-846',
#  'TREATMENT SURGERY': 'medical-N-847',
#  'CEMIPLIMAB-RWLC (LIBTAYO)': 'medical-N-848',
#  'EXTRACAPSULAR EXTENSION': 'medical-N-849',
#  'EXTRANODAL EXTENSION': 'medical-N-850',
#  'OTHER AREAS OF THE BODY': 'medical-N-851',
#  'PART 6': 'medical-N-852',
#  'RESEARCH': 'medical-N-853',
#  'DISTANT TUMORS': 'medical-N-854',
#  'STEREOTACTIC BODY RADIOTHERAPY (SBRT)': 'medical-N-855',
#  'HIGH DOSES OF RADIATION': 'medical-N-856',
#  'SMALL AREAS': 'medical-N-857',
#  'SUSPICIOUS LYMPH NODES': 'medical-N-858',
#  'SCANS': 'medical-N-859',
#  'UPPER BODY': 'medical-N-860',
#  'STOMACH': 'medical-N-861',
#  'PELVIS': 'medical-N-862',
#  'METASTATIC DISEASE': 'medical-N-863',
#  '3 TO 5 TREATMENTS': 'medical-N-864',
#  'METASTATIC CSCC': 'medical-N-865',
#  'OTHER TYPES OF SKIN CANCER': 'medical-N-866',
#  'FOLLOWUP EXAMS': 'medical-N-867',
#  'ENTIRE BODY': 'medical-N-868',
#  'CANCER SITE': 'medical-N-869',
#  'LOCAL CSCC': 'medical-N-870',
#  'FIRST 2 YEARS AFTER TREATMENT': 'medical-N-871',
#  'PAPER GOWN': 'medical-N-872',
#  'DRAPE': 'medical-N-873',
#  'UNDERGARMENTS': 'medical-N-874',
#  'FIRST 2 YEARS': 'medical-N-875',
#  '6 TO 12 MONTHS': 'medical-N-876',
#  'ONCE OR TWICE A YEAR': 'medical-N-877',
#  'ANOTHER 3 YEARS': 'medical-N-878',
#  'NCCN EXPERTS': 'medical-N-879',
#  '3 TO 6 MONTHS': 'medical-N-880',
#  'NEXT 3 YEARS': 'medical-N-881',
#  '6 MONTHS': 'medical-N-882',
#  'PHYSICAL EXAMS': 'medical-N-883',
#  'SKIN CHECKS': 'medical-N-884',
#  'FIRST YEAR': 'medical-N-885',
#  '2 TO 3 MONTHS': 'medical-N-886',
#  'SECOND YEAR': 'medical-N-887',
#  '2 TO 4 MONTHS': 'medical-N-888',
#  '4 TO 6 MONTHS': 'medical-N-889',
#  'PATIENT': 'medical-N-890',
#  'CT SCANS': 'medical-N-891',
#  'OTHER PARTS OF YOUR BODY': 'medical-N-892',
#  'FOLLOW-UP EXAM SCHEDULES': 'medical-N-893',
#  'GUIDE': 'medical-N-894',
#  'CHRONIC MYELOID LEUKEMIA (CML)': 'medical-N-895',
#  'BLOOD CANCER': 'medical-N-896',
#  'ABNORMAL GENE': 'medical-N-897',
#  'CHROMOSOME 9': 'medical-N-898',
#  'CHROMOSOME 22': 'medical-N-899',
#  'BCR::ABL1 GENE': 'medical-N-900',
#  'PHILADELPHIA (PH) CHROMOSOME': 'medical-N-901',
#  'OXYGEN': 'medical-N-902',
#  'NUTRIENTS': 'medical-N-903',
#  'WASTE': 'medical-N-904',
#  'PLASMA': 'medical-N-905',
#  'RED BLOOD CELLS': 'medical-N-906',
#  'PLATELETS': 'medical-N-907',
#  'CANCER CARE': 'medical-N-908',
#  'CURRENT CARE RECOMMENDATIONS': 'medical-N-909',
#  'RESPECTED EXPERTS': 'medical-N-910',
#  'LEADING CANCER CENTERS': 'medical-N-911',
#  'PATIENT OUTCOMES': 'medical-N-912',
#  'RED BLOOD CELLS (RBCS OR ERYTHROCYTES)': 'medical-N-913',
#  'WHITE BLOOD CELLS (WBCS OR LEUKOCYTES)': 'medical-N-914',
#  'GRANULOCYTES': 'medical-N-915',
#  'MONOCYTES': 'medical-N-916',
#  'INFECTIONS': 'medical-N-917',
#  'PLATELETS (PLTS OR THROMBOCYTES)': 'medical-N-918',
#  'CML': 'medical-N-919',
#  'CHRONIC': 'medical-N-920',
#  'WHITE BLOOD CELL': 'medical-N-921',
#  'NEUTROPHILS': 'medical-N-922',
#  'EOSINOPHILS': 'medical-N-923',
#  'BASOPHILS': 'medical-N-924',
#  'BLOOD CELLS': 'medical-N-925',
#  'HEMATOPOIETIC STEM CELLS': 'medical-N-926',
#  'BONE MARROW': 'medical-N-927',
#  'WBCS': 'medical-N-928',
#  'LEUKOCYTES': 'medical-N-929',
#  'PLTS': 'medical-N-930',
#  'THROMBOCYTES': 'medical-N-931',
#  'CHRONIC MYELOID LEUKEMIA': 'medical-N-932',
#  'BLOOD (HEMATOPOIETIC) STEM CELLS': 'medical-N-933',
#  'DIFFERENTIATION': 'medical-N-934',
#  'RBCS': 'medical-N-935',
#  'PROGENITOR CELLS': 'medical-N-936',
#  'PRECURSOR CELLS': 'medical-N-937',
#  'LYMPHOID PROGENITOR CELLS': 'medical-N-938',
#  'LYMPHOBLASTS': 'medical-N-939',
#  'PHILADELPHIA CHROMOSOME': 'medical-N-940',
#  'BCR::ABL1': 'medical-N-941',
#  'MYELOID PROGENITOR CELLS': 'medical-N-942',
#  'MYELOBLASTS': 'medical-N-943',
#  'NON-LYMPHOID BLOOD CELLS': 'medical-N-944',
#  'BLASTS': 'medical-N-945',
#  'BLOOD STEM CELLS': 'medical-N-946',
#  'BLAST PHASE CML': 'medical-N-947',
#  'BP-CML': 'medical-N-948',
#  'BCR::ABL': 'medical-N-949',
#  'PH': 'medical-N-950',
#  'PHILADELPHIA CHROMOSOME (PH)': 'medical-N-951',
#  'BCR::ABL1 PROTEIN': 'medical-N-952',
#  'CML SPECIALIST': 'medical-N-953',
#  'CML PHASES': 'medical-N-954',
#  'TESTS': 'medical-N-955',
#  'MEDICAL DOCUMENTS': 'medical-N-956',
#  'PRIMARY CARE PHYSICIAN (PCP)': 'medical-N-957',
#  'BONE MARROW TESTS': 'medical-N-958',
#  'CML BIOMARKER': 'medical-N-959',
#  'GENETIC CHANGES': 'medical-N-960',
#  'HEART TESTS': 'medical-N-961',
#  'CML TREATMENT PLAN': 'medical-N-962',
#  'CML DIAGNOSIS': 'medical-N-963',
#  'CML TREATMENT': 'medical-N-964',
#  'PEERS': 'medical-N-965',
#  'MEALS': 'medical-N-966',
#  'EMOTIONAL SUPPORT': 'medical-N-967',
#  'TELEHEALTH VISITS': 'medical-N-968',
#  'CAREGIVERS': 'medical-N-969',
#  'NON-SMALL CELL LUNG CANCER (NSCLC)': 'medical-N-970',
#  'LUNG CANCER CELLS': 'medical-N-971',
#  'NSCLC': 'medical-N-972',
#  'CARCINOMA': 'medical-N-973',
#  'BRONCHI': 'medical-N-974',
#  'BRONCHIOLI': 'medical-N-975',
#  'ALVEOLI': 'medical-N-976',
#  'ADENOCARCINOMA': 'medical-N-977',
#  'MUCUS': 'medical-N-978',
#  'LARGE CELL CARCINOMA': 'medical-N-979',
#  'AIRWAYS': 'medical-N-980',
#  'EARLY AND LOCALLY ADVANCED LUNG CANCERS': 'medical-N-981',
#  'TISSUE LINING AROUND THE LUNG': 'medical-N-982',
#  'OTHER ORGANS': 'medical-N-983',
#  'CANCER STAGE': 'medical-N-984',
#  'LUNG TISSUE LINING': 'medical-N-985',
#  'NCCN GUIDELINES FOR PATIENTS® EARLY AND LOCALLY ADVANCED NON-SMALL CELL LUNG CANCER 2024': 'medical-N-986',
#  'STAGES I': 'medical-N-987',
#  'STAGES II': 'medical-N-988',
#  'STAGES III': 'medical-N-989',
#  'STAGES IV': 'medical-N-990',
#  'STAGE 1': 'medical-N-991',
#  'STAGE 2': 'medical-N-992',
#  'STAGE 3': 'medical-N-993',
#  'EARLY NSCLC': 'medical-N-994',
#  'LOCALLY ADVANCED': 'medical-N-995',
#  'EARLY AND LOCALLY ADVANCED CANCERS': 'medical-N-996',
#  'STAGE 4 CANCER': 'medical-N-997',
#  'CURRENT PRACTICES': 'medical-N-998',
#  'MULTIPLE TREATMENTS': 'medical-N-999',
#  ...}

# %%
total_edges = sum(len(node.edges) for node in medical_nodes.values())//2
print("Total edges:", total_edges)
# Out:
# Total edges: 67566

# %%
novel_nodes_df = nodes_to_dataframe(novel_nodes)
novel_nodes_df = novel_nodes_df.sort_values(by=["source", "node_type", "id"]).reset_index(drop=True)
novel_nodes_df
# Out:
#                    id node_type     source  \
# 0           novel-N-0         N
# 1           novel-N-1         N
# 2          novel-N-10         N
# 3         novel-N-100         N
# 4        novel-N-1000         N
# ...               ...       ...        ...
# 124473  novel-999-S-0         S  novel-999
# 124474  novel-999-S-1         S  novel-999
# 124475  novel-999-S-2         S  novel-999
# 124476  novel-999-S-3         S  novel-999
# 124477  novel-999-S-4         S  novel-999
#
#                                                   content  \
# 0                                            JULIA MILLER
# 1                    ONLINE DISTRIBUTED PROOFREADING TEAM
# 2                                                   MAYAB
# 3                                                 STREAMS
# 4                                                  PRISON
# ...                                                   ...
# 124473  For hours, the rebels unsuccessfully attempted...
# 124474  The day's casualties included three killed and...
# 124475  Capt. Munch was injured when his horse was sho...
# 124476  On the morning of April 7, Gen. Buell arrived,...
# 124477  This was their first battle, having only recen...
#
#                                                     edges
# 0       {'novel-0-S-0': 1, 'novel-0-S-0-R-0': 1, 'nove...
# 1       {'novel-0-S-0': 1, 'novel-0-S-0-R-1': 1, 'nove...
# 2       {'novel-0-S-1': 1, 'novel-24-S-1': 1, 'novel-2...
# 3       {'novel-3-S-1': 1, 'novel-3-S-1-R-1': 1, 'nove...
# 4       {'novel-39-S-2': 1, 'novel-39-S-2-R-4': 1, 'no...
# ...                                                   ...
# 124473  {'novel-N-15582': 1, 'novel-N-18096': 1, 'nove...
# 124474  {'novel-N-15514': 1, 'novel-N-15607': 1, 'nove...
# 124475  {'novel-N-18430': 1, 'novel-N-13310': 1, 'nove...
# 124476  {'novel-N-18434': 1, 'novel-N-17888': 1, 'nove...
# 124477  {'novel-N-18437': 1, 'novel-N-1429': 1, 'novel...
#
# [124478 rows x 5 columns]

# %%
novel_entities
# Out:
# {'JULIA MILLER': 'novel-N-0',
#  'ONLINE DISTRIBUTED PROOFREADING TEAM': 'novel-N-1',
#  'HTTP://WWW.PGDP.NET': 'novel-N-2',
#  'THE INTERNET ARCHIVE/AMERICAN LIBRARIES': 'novel-N-3',
#  '[TN-#]': 'novel-N-4',
#  'OE LIGATURES': 'novel-N-5',
#  '[SUN]': 'novel-N-6',
#  '[=A]': 'novel-N-7',
#  '[C]': 'novel-N-8',
#  'VESTIGES OF THE MAYAS': 'novel-N-9',
#  'MAYAB': 'novel-N-10',
#  'ASIA': 'novel-N-11',
#  'AFRICA': 'novel-N-12',
#  'AUGUSTUS LE PLONGEON, M. D.': 'novel-N-13',
#  'AMERICAN ANTIQUARIAN SOCIETY OF WORCESTER, MASS.': 'novel-N-14',
#  'CALIFORNIA ACADEMY OF SCIENCES': 'novel-N-15',
#  'SCIENTIFIC SOCIETIES': 'novel-N-16',
#  'ESSAYS AND SCIENTIFIC WORKS': 'novel-N-17',
#  'NEW YORK': 'novel-N-18',
#  'JOHN POLHEMUS': 'novel-N-19',
#  'PRINTER AND STATIONER': 'novel-N-20',
#  '1881': 'novel-N-21',
#  'MR. PIERRE LORILLARD': 'novel-N-22',
#  'AMERICAN ARCHAEOLOGY': 'novel-N-23',
#  'CENTRAL AMERICA': 'novel-N-24',
#  'FOREIGN EXPLORERS': 'novel-N-25',
#  'AMERICAN EXPLORERS': 'novel-N-26',
#  'INCAS': 'novel-N-27',
#  'PERU': 'novel-N-28',
#  'MAYAS': 'novel-N-29',
#  'YUCATAN': 'novel-N-30',
#  'DECEMBER 15, 1881': 'novel-N-31',
#  'ACT OF CONGRESS': 'novel-N-32',
#  'DECEMBER, 1881': 'novel-N-33',
#  'AUGUSTUS LE PLONGEON': 'novel-N-34',
#  'LIBRARIAN OF CONGRESS': 'novel-N-35',
#  'WASHINGTON, D.C.': 'novel-N-36',
#  'PENINSULA': 'novel-N-37',
#  'GULF OF MEXICO': 'novel-N-38',
#  'CARIBBEAN SEA': 'novel-N-39',
#  "17 DEG. 30' OF LATITUDE NORTH": 'novel-N-40',
#  "21 DEG. 50' OF LATITUDE NORTH": 'novel-N-41',
#  '88 DEG. OF LONGITUDE WEST': 'novel-N-42',
#  '91 DEG. OF LONGITUDE WEST': 'novel-N-43',
#  'GREENWICH MERIDIAN': 'novel-N-44',
#  'FOSSILIFEROUS LIMESTONE FORMATION': 'novel-N-45',
#  'OFFICE OF THE LIBRARIAN OF CONGRESS': 'novel-N-46',
#  "17 DEG. 30'": 'novel-N-47',
#  "21 DEG. 50'": 'novel-N-48',
#  '88 DEG.': 'novel-N-49',
#  '91 DEG.': 'novel-N-50',
#  'LANDSCAPE': 'novel-N-51',
#  'PALM TREES': 'novel-N-52',
#  'ARTIFICIAL MOUNDS': 'novel-N-53',
#  'SHRUBS': 'novel-N-54',
#  'NORTHWESTERN COAST': 'novel-N-55',
#  'LOW, NARROW RANGE OF HILLS': 'novel-N-56',
#  '500 FEET': 'novel-N-57',
#  'RUINED CITY OF UXMAL': 'novel-N-58',
#  'EASTERN COAST': 'novel-N-59',
#  'ASCENSION BAY': 'novel-N-60',
#  'RED OXIDE OF IRON': 'novel-N-61',
#  'MARBLE': 'novel-N-62',
#  'SCULPTURED ORNAMENTS': 'novel-N-63',
#  'MONUMENTS AT UXMAL': 'novel-N-64',
#  'INHABITANTS OF YUCATAN': 'novel-N-65',
#  'OCHER': 'novel-N-66',
#  'MARBLE SLABS': 'novel-N-67',
#  'SURFACE OF THE COUNTRY': 'novel-N-68',
#  'STONES': 'novel-N-69',
#  'MID-OCEAN': 'novel-N-70',
#  'VOLCANIC FORCES': 'novel-N-71',
#  'SEA': 'novel-N-72',
#  'CENTURIES AGO': 'novel-N-73',
#  'ISOLATED COLUMNS OF KATUNS': 'novel-N-74',
#  '1M. 50C.': 'novel-N-75',
#  'MINERALS': 'novel-N-76',
#  'LITHOGRAPHIC STONES': 'novel-N-77',
#  'MEXICO': 'novel-N-78',
#  'GUATEMALA': 'novel-N-79',
#  'CUBA': 'novel-N-80',
#  'WEST INDIA ISLANDS': 'novel-N-81',
#  'EARTHQUAKES': 'novel-N-82',
#  'KATUNS': 'novel-N-83',
#  'CAVES': 'novel-N-84',
#  'SENOTES': 'novel-N-85',
#  'GASES': 'novel-N-86',
#  'STALACTITES': 'novel-N-87',
#  'STALAGMITES': 'novel-N-88',
#  'SPRINGS': 'novel-N-89',
#  'WATER': 'novel-N-90',
#  'SHRIMPS': 'novel-N-91',
#  'FISHES': 'novel-N-92',
#  'WATER CURRENTS': 'novel-N-93',
#  'RIVER': 'novel-N-94',
#  'STREAMLETS': 'novel-N-95',
#  'BIRDS': 'novel-N-96',
#  'WILD BEASTS': 'novel-N-97',
#  'DRY SEASON': 'novel-N-98',
#  'COLUMNS': 'novel-N-99',
#  'STREAMS': 'novel-N-100',
#  'RIVERS': 'novel-N-101',
#  'ROOTS OF TREES': 'novel-N-102',
#  'PRECIPITOUS BRINKS': 'novel-N-103',
#  'CABLES': 'novel-N-104',
#  'ROPES': 'novel-N-105',
#  'NATIVES': 'novel-N-106',
#  'BATH': 'novel-N-107',
#  'CIRCULAR HOLES': 'novel-N-108',
#  'PERPENDICULAR WALLS': 'novel-N-109',
#  'SUBTERRANEAN GASES': 'novel-N-110',
#  'COUNTRY': 'novel-N-111',
#  'CURRENTS': 'novel-N-112',
#  'THERMAL MINERAL WATER': 'novel-N-113',
#  'SULPHUROUS ODOR': 'novel-N-114',
#  'VAPOR': 'novel-N-115',
#  'ABORIGINES': 'novel-N-116',
#  'STORIES': 'novel-N-117',
#  'PHENOMENA': 'novel-N-118',
#  'SENOTE': 'novel-N-119',
#  'WHISPER': 'novel-N-120',
#  'SURFACE OF THE WATER': 'novel-N-121',
#  'LEVEL OF THE WATER': 'novel-N-122',
#  'CERTAIN CENOTES': 'novel-N-123',
#  'TURBID': 'novel-N-124',
#  'TRANQUIL SURFACE': 'novel-N-125',
#  'BOILING': 'novel-N-126',
#  'LAKES': 'novel-N-127',
#  'WHITE MEN': 'novel-N-128',
#  'AGUADAS': 'novel-N-129',
#  'UNDERGROUND CURRENT': 'novel-N-130',
#  'ANCIENT CITY OF MAYAPAN': 'novel-N-131',
#  'WATER SUPPLY': 'novel-N-132',
#  'SUBTERRANEAN STREAM': 'novel-N-133',
#  'CENOTE OF MUCUYCHE': 'novel-N-134',
#  'AGUADA': 'novel-N-135',
#  'UXMAL': 'novel-N-136',
#  'ARTIFICIAL RESERVOIRS': 'novel-N-137',
#  'TERRACES': 'novel-N-138',
#  'COURTS OF MONUMENTS': 'novel-N-139',
#  'CLOUDS': 'novel-N-140',
#  'WELLS': 'novel-N-141',
#  'CENOTES': 'novel-N-142',
#  "GOVERNOR'S HOUSE": 'novel-N-143',
#  'CAVE ENTRANCE': 'novel-N-144',
#  'COOL CURRENT OF AIR': 'novel-N-145',
#  'INDIANS': 'novel-N-146',
#  'VILLAGE OF CHEMAX': 'novel-N-147',
#  'FIFTY MILES': 'novel-N-148',
#  'VALLADOLID': 'novel-N-149',
#  'EASTERN FRONTIER': 'novel-N-150',
#  'TERRITORIES OCCUPIED BY THE SANTA CRUZ INDIANS': 'novel-N-151',
#  'RUINS OF KABA': 'novel-N-152',
#  'TWO EXTENSIVE SHEETS OF WATER': 'novel-N-153',
#  'INHABITANTS OF VALLADOLID': 'novel-N-154',
#  'EXCELLENT FISHES': 'novel-N-155',
#  'CAVE': 'novel-N-156',
#  'CHYMAX': 'novel-N-157',
#  'SANTA CRUZ INDIANS': 'novel-N-158',
#  'KABA': 'novel-N-159',
#  'COAST': 'novel-N-160',
#  'LOWLANDS': 'novel-N-161',
#  'SLOUGHS': 'novel-N-162',
#  'MANGROVES': 'novel-N-163',
#  'SEA BIRDS': 'novel-N-164',
#  'WATER FOWL': 'novel-N-165',
#  'SNIPE': 'novel-N-166',
#  'CRANE': 'novel-N-167',
#  'FLAMINGOS': 'novel-N-168',
#  'SEA GULLS': 'novel-N-169',
#  'PELICAN': 'novel-N-170',
#  'AIR': 'novel-N-171',
#  'VEGETATION': 'novel-N-172',
#  'CLIMATE': 'novel-N-173',
#  'TROPICS': 'novel-N-174',
#  'MEXICAN GULF': 'novel-N-175',
#  'SEA BREEZES': 'novel-N-176',
#  'MALARIA': 'novel-N-177',
#  'NOXIOUS GASES': 'novel-N-178',
#  'FORESTS': 'novel-N-179',
#  'PLANTS': 'novel-N-180',
#  'OXYGEN': 'novel-N-181',
#  'EPIDEMIC FORM': 'novel-N-182',
#  'UNACCLIMATED FOREIGNERS': 'novel-N-183',
#  'SMALLPOX': 'novel-N-184',
#  'OTHER DISEASES': 'novel-N-185',
#  'RAINY SEASON': 'novel-N-186',
#  'MERIDA': 'novel-N-187',
#  'POPULATION': 'novel-N-188',
#  'AUTHORITIES': 'novel-N-189',
#  'STREETS': 'novel-N-190',
#  'VEGETABLE AND ANIMAL MATTER': 'novel-N-191',
#  'MIASMAS': 'novel-N-192',
#  'VAPORS': 'novel-N-193',
#  'STAGNANT WATERS': 'novel-N-194',
#  'HEALTH LAWS': 'novel-N-195',
#  'ISLAND OF COZUMEL': 'novel-N-196',
#  'OLD AGE': 'novel-N-197',
#  'ACCIDENT': 'novel-N-198',
#  'THERMOMETER': 'novel-N-199',
#  'JULY': 'novel-N-200',
#  'AUGUST': 'novel-N-201',
#  'DECEMBER': 'novel-N-202',
#  'JANUARY': 'novel-N-203',
#  'JUNE': 'novel-N-204',
#  'TREES': 'novel-N-205',
#  'LEAVES': 'novel-N-206',
#  'MARCH': 'novel-N-207',
#  'APRIL': 'novel-N-208',
#  '80 DEG. FAR.': 'novel-N-209',
#  '96 DEG.': 'novel-N-210',
#  '65 DEG.': 'novel-N-211',
#  '1847': 'novel-N-212',
#  'ARABLE LOAM': 'novel-N-213',
#  'EASTERN PARTS OF THE STATE': 'novel-N-214',
#  'SOUTHERN PARTS OF THE STATE': 'novel-N-215',
#  'RED CLAY': 'novel-N-216',
#  'SUGAR CANE': 'novel-N-217',
#  'YUCA ROOT': 'novel-N-218',
#  'STARCH': 'novel-N-219',
#  'MOISTURE': 'novel-N-220',
#  'MAY': 'novel-N-221',
#  'BUDS': 'novel-N-222',
#  'FLOWERS': 'novel-N-223',
#  'HUMANS': 'novel-N-224',
#  'METALLIC MINES': 'novel-N-225',
#  'VEGETABLE PRODUCTIONS': 'novel-N-226',
#  'MAHOGANY': 'novel-N-227',
#  'CEDAR': 'novel-N-228',
#  'ZAPOTILLO TREES': 'novel-N-229',
#  'EASTERN PORTIONS': 'novel-N-230',
#  'SOUTHERN PORTIONS': 'novel-N-231',
#  'LOGWOOD': 'novel-N-232',
#  'MORA': 'novel-N-233',
#  'WOOD': 'novel-N-234',
#  'INDIANS OF SANTA CRUZ': 'novel-N-235',
#  'AGENTS': 'novel-N-236',
#  'BELIZE': 'novel-N-237',
#  'COFFEE': 'novel-N-238',
#  'VANILLA': 'novel-N-239',
#  'TOBACCO': 'novel-N-240',
#  'INDIA-RUBBER': 'novel-N-241',
#  'ROSINS OF VARIOUS KINDS': 'novel-N-242',
#  'COPAL': 'novel-N-243',
#  'FERTILE TERRITORIES': 'novel-N-244',
#  'WHITES': 'novel-N-245',
#  'HENNEQUEN PLANT': 'novel-N-246',
#  'AGAVE SISALENSIS': 'novel-N-247',
#  'STONY SOIL': 'novel-N-248',
#  'FILAMENT': 'novel-N-249',
#  'OBJECTS MANUFACTURED FROM IT': 'novel-N-250',
#  'PRINCIPAL ARTICLE OF EXPORT': 'novel-N-251',
#  'SOURCE OF WEALTH': 'novel-N-252',
#  'YUCATECAN': 'novel-N-253',
#  'CORDAGE': 'novel-N-254',
#  'UNITED STATES': 'novel-N-255',
#  'EUROPE': 'novel-N-256',
#  'LANDOWNERS': 'novel-N-257',
#  'MAIZE': 'novel-N-258',
#  'STAPLE ARTICLE OF FOOD': 'novel-N-259',
#  'HENNEQUEN FIELDS': 'novel-N-260',
#  'PLANT': 'novel-N-261',
#  'CARE': 'novel-N-262',
#  'YUCATECANS': 'novel-N-263',
#  'POORER CLASSES': 'novel-N-264',
#  'SUGAR': 'novel-N-265',
#  'SOUTHERN DISTRICTS': 'novel-N-266',
#  'EASTERN DISTRICTS': 'novel-N-267',
#  'HABANA': 'novel-N-268',
#  'MIXED BLOOD': 'novel-N-269',
#  'FAMILIES': 'novel-N-270',
#  'CAUCASIAN RACE': 'novel-N-271',
#  'RACES': 'novel-N-272',
#  'DWARFISH RACE': 'novel-N-273',
#  'GIANTS': 'novel-N-274',
#  'BONES': 'novel-N-275',
#  'PORTRAITS': 'novel-N-276',
#  "CHAACMOL'S FUNERAL CHAMBER": 'novel-N-277',
#  'CHICHEN-ITZA': 'novel-N-278',
#  'SIAMESE RACE OF COPAN': 'novel-N-279',
#  'NAHUALT FROM PALENQUE': 'novel-N-280',
#  'CHRISTIAN ERA': 'novel-N-281',
#  'MAYA CIVILIZATION': 'novel-N-282',
#  'WEST': 'novel-N-283',
#  'LANDA': 'novel-N-284',
#  'COGOLLUDO': 'novel-N-285',
#  'HISTORIANS': 'novel-N-286',
#  'NOHNIAL': 'novel-N-287',
#  'BEARDED MEN': 'novel-N-288',
#  'EAST': 'novel-N-289',
#  'BAS-RELIEF': 'novel-N-290',
#  'ALMOND-EYED': 'novel-N-291',
#  'FLAT-NOSED': 'novel-N-292',
#  'NAHUALT': 'novel-N-293',
#  'PALENQUE': 'novel-N-294',
#  'CENIAL': 'novel-N-295',
#  'ORNAMENTS FOR OUR DAUGHTERS': 'novel-N-296',
#  'WARS': 'novel-N-297',
#  'INVASIONS': 'novel-N-298',
#  'SOCIAL AND RELIGIOUS CONVULSIONS': 'novel-N-299',
#  'MEXICAN GOVERNMENT': 'novel-N-300',
#  'PROPERTY OWNERS': 'novel-N-301',
#  'WALL INSCRIPTIONS': 'novel-N-302',
#  'BUILDERS': 'novel-N-303',
#  'ENDURING STRUCTURES': 'novel-N-304',
#  'ART OF DESIGNING PLANS': 'novel-N-305',
#  'ART OF CREATING ORNAMENTS': 'novel-N-306',
#  'ART OF CARVING ON STONE': 'novel-N-307',
#  'PRECIOUS VOLUMES': 'novel-N-308',
#  'EDIFICES': 'novel-N-309',
#  'MONUMENTS': 'novel-N-310',
#  'INSCRIPTIONS': 'novel-N-311',
#  'WALLS': 'novel-N-312',
#  'STRUCTURES': 'novel-N-313',
#  'ANCIENT BUILDERS': 'novel-N-314',
#  'MECHANICS': 'novel-N-315',
#  'OUR CIVILIZATION': 'novel-N-316',
#  'LIBRARY VOLUMES': 'novel-N-317',
#  'INTERPRETERS': 'novel-N-318',
#  'ANCIENT CIVILIZATIONS': 'novel-N-319',
#  'FUTURE ARCHAEOLOGISTS': 'novel-N-320',
#  '1517': 'novel-N-321',
#  'SPANIARDS': 'novel-N-322',
#  'STONE MONUMENTS': 'novel-N-323',
#  'LARGE CITIES': 'novel-N-324',
#  'BEAUTIFUL MONUMENTS': 'novel-N-325',
#  'SPAIN': 'novel-N-326',
#  'INHABITANTS': 'novel-N-327',
#  'CIVILIZED PEOPLE': 'novel-N-328',
#  'WHITE COTTON': 'novel-N-329',
#  'LARGE BOATS': 'novel-N-330',
#  'SAILS': 'novel-N-331',
#  'WELL CONSTRUCTED ROADS': 'novel-N-332',
#  'CAUSEWAYS': 'novel-N-333',
#  'ROMAN STRUCTURES': 'novel-N-334',
#  'MRS. LE PLONGEON': 'novel-N-335',
#  'MAJESTIC MONUMENTS': 'novel-N-336',
#  'AKE': 'novel-N-337',
#  'MAYAPAN': 'novel-N-338',
#  'NEW YORK WORLD': 'novel-N-339',
#  'AUTHOR': 'novel-N-340',
#  'WHITE COTTON HABILIMENTS': 'novel-N-341',
#  'WELL CONSTRUCTED ROADS AND CAUSEWAYS': 'novel-N-342',
#  'ITALY': 'novel-N-343',
#  'ENGLAND': 'novel-N-344',
#  'FRANCE': 'novel-N-345',
#  'ANCIENT RUINED CITIES OF YUCATAN': 'novel-N-346',
#  'MONUMENTAL RUINS': 'novel-N-347',
#  '2024-07': 'novel-N-348',
#  'PROGRESO': 'novel-N-349',
#  'STEPHENS': 'novel-N-350',
#  'WALDECK': 'novel-N-351',
#  'NORMAN': 'novel-N-352',
#  'FREDEICHTAL': 'novel-N-353',
#  'MR. CHARNAY': 'novel-N-354',
#  'ANTIQUE SHRINES AND PALACES OF THE MAYAS': 'novel-N-355',
#  'WRITERS': 'novel-N-356',
#  'MYSTERIES': 'novel-N-357',
#  'ORNAMENTS AND INSCRIPTIONS': 'novel-N-358',
#  'YEARS OF CLOSE OBSERVATION AND PATIENT LABOR': 'novel-N-359',
#  'ENIGMA': 'novel-N-360',
#  'MAYA MONUMENTS': 'novel-N-361',
#  'PHOTOGRAPHS': 'novel-N-362',
#  'ALL THE MONUMENTS': 'novel-N-363',
#  'SURVEYED': 'novel-N-364',
#  'ACCURATE PLANS': 'novel-N-365',
#  'HUMAN MIND AND HUMAN INCLINATIONS AND WANTS': 'novel-N-366',
#  'PLANS': 'novel-N-367',
#  'DESIGNS': 'novel-N-368',
#  'MURAL PAINTINGS': 'novel-N-369',
#  'FUNERAL CHAMBER OF CHAACMOL': 'novel-N-370',
#  'EASTERN WALL OF THE GYMNASIUM AT CHICHEN-ITZZA': 'novel-N-371',
#  'SHRINE DEDICATED TO THE GOD OF THE PLAYERS AT BALL': 'novel-N-372',
#  'FIGURE OF CHAACMOL IN BATTLE': 'novel-N-373',
#  'SHIELD': 'novel-N-374',
#  'ROUND GREEN SPOTS': 'novel-N-375',
#  'ORNAMENTS': 'novel-N-376',
#  'ENTABLATURE OF THE SAME MONUMENT': 'novel-N-377',
#  'TIGERS': 'novel-N-378',
#  'CHAACMOL': 'novel-N-379',
#  'BALAM': 'novel-N-380',
#  'MOUND': 'novel-N-381',
#  'THICKET': 'novel-N-382',
#  'EASTERLY DIRECTION': 'novel-N-383',
#  'SLABS': 'novel-N-384',
#  'BAS-RELIEFS OF SPOTTED TIGERS EATING HUMAN HEARTS': 'novel-N-385',
#  'TRACES OF THE COLORS': 'novel-N-386',
#  'ROUND DOTS': 'novel-N-387',
#  'TIGER SPOTS': 'novel-N-388',
#  'WARRIOR IN BATTLE': 'novel-N-389',
#  'BUILDING': 'novel-N-390',
#  'STATUE': 'novel-N-391',
#  'DEBRIS': 'novel-N-392',
#  'SPOTTED TIGERS': 'novel-N-393',
#  'HUMAN HEARTS': 'novel-N-394',
#  'BAS-RELIEFS': 'novel-N-395',
#  'SHIELD OF THE WARRIOR': 'novel-N-396',
#  'NARRATOR': 'novel-N-397',
#  'GROUND': 'novel-N-398',
#  'HUMAN HEAD': 'novel-N-399',
#  'DYING PERSON': 'novel-N-400',
#  'CHALDEAN DEITIES': 'novel-N-401',
#  'EGYPTIAN DEITIES': 'novel-N-402',
#  'HEADLESS STATUE': 'novel-N-403',
#  'SLAB': 'novel-N-404',
#  'DYING WARRIOR': 'novel-N-405',
#  'EGYPTIAN MUMMIES': 'novel-N-406',
#  'FLAMES': 'novel-N-407',
#  'SPIRIT': 'novel-N-408',
#  'BODY': 'novel-N-409',
#  'MAUSOLEUM': 'novel-N-410',
#  'WARRIOR WITH THE SHIELD COVERED WITH ROUND DOTS': 'novel-N-411',
#  'ARA MILITARIS': 'novel-N-412',
#  'PARROT SPECIE': 'novel-N-413',
#  'TOTEM': 'novel-N-414',
#  'MOO': 'novel-N-415',
#  'MACAW': 'novel-N-416',
#  'IDEOGRAPHIC WRITINGS': 'novel-N-417',
#  'KINICH-KAKMO': 'novel-N-418',
#  'TEMPLES': 'novel-N-419',
#  'IZAMAL': 'novel-N-420',
#  'SPANISH CONQUEST': 'novel-N-421',
#  'COGLLUDO': 'novel-N-422',
#  'LIZANA': 'novel-N-423',
#  'BIRD OF THE PARROT SPECIE': 'novel-N-424',
#  'MACA': 'novel-N-425',
#  'TWO MONTHS': 'novel-N-426',
#  'THREE LEVEL FLOORS PAINTED WITH YELLOW OCHRE': 'novel-N-427',
#  'LARGE STONE URN': 'novel-N-428',
#  'COLONEL D. DANIEL TRACONIS': 'novel-N-429',
#  'GRAYISH DUST': 'novel-N-430',
#  'COVER OF A TERRA COTTA POT ALSO PAINTED YELLOW': 'novel-N-431',
#  'MACRE': 'novel-N-432',
#  'LARGE BALL OF JADE': 'novel-N-433',
#  'HEAD OF THE COLOSSAL STATUE': 'novel-N-434',
#  'NATIONAL MUSEUM OF MEXICO': 'novel-N-435',
#  'GUNBOAT LIBERTAD': 'novel-N-436',
#  'SECOND STONE URN': 'novel-N-437',
#  'REDDISH SUBSTANCE': 'novel-N-438',
#  'JADE ORNAMENTS': 'novel-N-439',
#  'ORGANIC MATTER': 'novel-N-440',
#  'OPEN VESSEL': 'novel-N-441',
#  'PROFESSOR THOMPSON': 'novel-N-442',
#  'WORCESTER, MASS.': 'novel-N-443',
#  'MR. STEPHEN SALISBURY, JR.': 'novel-N-444',
#  'WORCESTER': 'novel-N-445',
#  'MASS.': 'novel-N-446',
#  'URN': 'novel-N-447',
#  'HEART': 'novel-N-448',
#  'VISCERA': 'novel-N-449',
#  'DUST': 'novel-N-450',
#  'BRAINS': 'novel-N-451',
#  '_CHAACMOL_': 'novel-N-452',
#  'FRIENDS': 'novel-N-453',
#  'RELATIVES': 'novel-N-454',
#  'REMAINS': 'novel-N-455',
#  'CHIEFTAIN': 'novel-N-456',
#  'SCENE': 'novel-N-457',
#  'FUNERAL CHAMBER': 'novel-N-458',
#  'CORPSE': 'novel-N-459',
#  'CREMATION': 'novel-N-460',
#  'PARTS': 'novel-N-461',
#  'CHILDREN': 'novel-N-462',
#  'ARROWHEADS': 'novel-N-463',
#  'FLINT': 'novel-N-464',
#  'CHALCEDONY': 'novel-N-465',
#  'BEADS': 'novel-N-466',
#  'NECKLACE': 'novel-N-467',
#  'BONE': 'novel-N-468',
#  'IVORY': 'novel-N-469',
#  'SHELLS': 'novel-N-470',
#  'PERIWINKLES': 'novel-N-471',
#  'FIGURE': 'novel-N-472',
#  'DRIED BLOOD': 'novel-N-473',
#  'SLAVES': 'novel-N-474',
#  'FUNERAL': 'novel-N-475',
#  'SCYTHIANS': 'novel-N-476',
#  'ROMANS': 'novel-N-477',
#  'HUMAN REMAINS': 'novel-N-478',
#  'STATUES OF DEAD PERSONAGES': 'novel-N-479',
#  'CHICHEN': 'novel-N-480',
#  'REINCARNATION': 'novel-N-481',
#  'EGYPTIANS': 'novel-N-482',
#  'HINDOOS': 'novel-N-483',
#  'EARTH': 'novel-N-484',
#  'STATUES': 'novel-N-485',
#  'DECEASED': 'novel-N-486',
#  'PRESENT ABORIGINES': 'novel-N-487',
#  'HANAL PIXAN': 'novel-N-488',
#  'FOOD FOR THE SPIRITS': 'novel-N-489',
#  'NOVEMBER': 'novel-N-490',
#  'FIELDS': 'novel-N-491',
#  'EGYPTIAN CUSTOM': 'novel-N-492',
#  'COFFINS': 'novel-N-493',
#  'MUMMIES': 'novel-N-494',
#  'SPIRIT OF THE DECEASED': 'novel-N-495',
#  'ORNAMENT': 'novel-N-496',
#  "CHAACMOL'S EFFIGY": 'novel-N-497',
#  'BADGE OF HIS RANK': 'novel-N-498',
#  'MARK OF AUTHORITY': 'novel-N-499',
#  'BURMAH': 'novel-N-500',
#  'EGYPTIAN': 'novel-N-501',
#  'ANALES DEL MUSEO NACIONAL': 'novel-N-502',
#  'CHICHEN-ITZ': 'novel-N-503',
#  'GOD OF THE NATURAL PRODUCTION OF THE EARTH': 'novel-N-504',
#  'NORTH AMERICAN REVIEW': 'novel-N-505',
#  'OCTOBER, 1880': 'novel-N-506',
#  'MR. SANCHEZ': 'novel-N-507',
#  'GOD OF WINE': 'novel-N-508',
#  'MEXICAN BACCHUS': 'novel-N-509',
#  'OILCLOTH': 'novel-N-510',
#  'HUT OF PALM LEAVES': 'novel-N-511',
#  'MEN': 'novel-N-512',
#  'GENERAL PALOMINO': 'novel-N-513',
#  'REVOLUTIONARY MOVEMENT': 'novel-N-514',
#  'DR. SEBASTIAN LERDO DE TEJADA': 'novel-N-515',
#  'GENERAL DIAZ': 'novel-N-516',
#  'RUINED TEMPLES': 'novel-N-517',
#  'PALACES': 'novel-N-518',
#  'PHALLIC WORSHIP OF THE NAHUALTS': 'novel-N-519',
#  'NORTHERN PARTS OF THE PENINSULA': 'novel-N-520',
#  'REGIONS WHERE THE NAHUALT INFLUENCE PREDIOMINATED': 'novel-N-521',
#  'ANCIENT TIMES': 'novel-N-522',
#  'CUSTOMS': 'novel-N-523',
#  'RELIGIOUS WORSHIP': 'novel-N-524',
#  'CITIES': 'novel-N-525',
#  'FAMILY, THAT OF CAN (SERPENT)': 'novel-N-526',
#  'NAME': 'novel-N-527',
#  'CAN FAMILY': 'novel-N-528',
#  'DEITY': 'novel-N-529',
#  "SYMBOL OF THE MASTODON'S HEAD": 'novel-N-530',
#  'CHICHEN ITZA': 'novel-N-531',
#  'CAN (SERPENT)': 'novel-N-532',
#  'FAMILY': 'novel-N-533',
#  "MASTODON'S HEAD": 'novel-N-534',
#  'SUN': 'novel-N-535',
#  'FIRE': 'novel-N-536',
#  'HIEROGLYPH': 'novel-N-537',
#  'CHALDEANS': 'novel-N-538',
#  'ELEMENT': 'novel-N-539',
#  'PICTURES': 'novel-N-540',
#  'CANS': 'novel-N-541',
#  'MASTODON': 'novel-N-542',
#  'RELIGION OF THE MASTODON': 'novel-N-543',
#  'RECIPROCAL FORCES OF NATURE': 'novel-N-544',
#  'BIG-NOSED INVADERS': 'novel-N-545',
#  'NAHUALTS': 'novel-N-546',
#  'CAPITAL': 'novel-N-547',
#  'SYMBOLS OF THEIR RELIGION': 'novel-N-548',
#  'BANCROFT': 'novel-N-549',
#  'THE NATIVE RACES OF THE PACIFIC STATES': 'novel-N-550',
#  'VOL. IV': 'novel-N-551',
#  'PAGE 277': 'novel-N-552',
#  'IDOLS': 'novel-N-553',
#  'MAYA ANTIQUITIES': 'novel-N-554',
#  'VOL. IV.': 'novel-N-555',
#  'GREAT MEN AND WOMEN': 'novel-N-556',
#  'PILGRIMS': 'novel-N-557',
#  'PRIESTS': 'novel-N-558',
#  'GODDESS': 'novel-N-559',
#  'OFFERINGS': 'novel-N-560',
#  'GOD OF WAR': 'novel-N-561',
#  'BATTLE': 'novel-N-562',
#  'KUKULCAN': 'novel-N-563',
#  'WINGED SERPENT': 'novel-N-564',
#  'MEXICANS': 'novel-N-565',
#  'GUETZALCOALT': 'novel-N-566',
#  'QUICHES': 'novel-N-567',
#  'CUCUMATZ': 'novel-N-568',
#  'ORACLES': 'novel-N-569',
#  'CONQUEST': 'novel-N-570',
#  'MAYA': 'novel-N-571',
#  'ANCESTORS': 'novel-N-572',
#  'ANCIENT MAYAS': 'novel-N-573',
#  'SYMBOLS': 'novel-N-574',
#  'DOUBLE-HEADED TIGERS': 'novel-N-575',
#  'DOUBLE-HEADED LIONS': 'novel-N-576',
#  'MASTODON HEAD': 'novel-N-577',
#  'CAN': 'novel-N-578',
#  'CATHOLICS': 'novel-N-579',
#  'SAINTS': 'novel-N-580',
#  'DULIA': 'novel-N-581',
#  'DEITIES': 'novel-N-582',
#  'KU': 'novel-N-583',
#  'IDOLATROUS RITES': 'novel-N-584',
#  'BARBAROUS OR HALF CIVILIZED TRIBES': 'novel-N-585',
#  'RELIGIOUS BELIEF': 'novel-N-586',
#  'IDOLATROUS SUPERSTITIONS': 'novel-N-587',
#  'FORM OF WORSHIP': 'novel-N-588',
#  'MONUMENTS OF UXMAL': 'novel-N-589',
#  'EVIDENCE': 'novel-N-590',
#  'HISTORY OF THE COUNTRY': 'novel-N-591',
#  'INVASION OF THE NAHUALTS': 'novel-N-592',
#  'BARBAROUS TRIBES': 'novel-N-593',
#  'HALF CIVILIZED TRIBES': 'novel-N-594',
#  'SUPERSTITIONS': 'novel-N-595',
#  'LANGUAGE OF THE ANCIENT MAYAS': 'novel-N-596',
#  'TIME': 'novel-N-597',
#  'POLITICAL CONVULSIONS': 'novel-N-598',
#  'RELIGIOUS CONVULSIONS': 'novel-N-599',
#  'MINGLING OF RACES': 'novel-N-600',
#  'PENINSULA OF YUCATAN': 'novel-N-601',
#  'VERNACULAR': 'novel-N-602',
#  'MOTHER TONGUE': 'novel-N-603',
#  'CHAACMULES': 'novel-N-604',
#  'TEKAL': 'novel-N-605',
#  'ITZAES': 'novel-N-606',
#  'NAHUALT INVADERS': 'novel-N-607',
#  'LAKE PETEN': 'novel-N-608',
#  'PETENITZ': 'novel-N-609',
#  'VALLEYS': 'novel-N-610',
#  'MANNERS': 'novel-N-611',
#  'LANGUAGE OF THEIR FOREFATHERS': 'novel-N-612',
#  'TIERRA DE GUERRA': 'novel-N-613',
#  'TABASCO': 'novel-N-614',
#  'CHIAPAS': 'novel-N-615',
#  'RIVER UZUMASINTA': 'novel-N-616',
#  'WHITE MAN': 'novel-N-617',
#  'MAYA LANGUAGE': 'novel-N-618',
#  'OLDEST TONGUES SPOKEN BY MAN': 'novel-N-619',
#  'WORDS': 'novel-N-620',
#  'EXPRESSIONS': 'novel-N-621',
#  'POLISHED LANGUAGES ON EARTH': 'novel-N-622',
#  'FOREFATHERS': 'novel-N-623',
#  'UZUMASINTA RIVER': 'novel-N-624',
#  'ENGLISH WORDS': 'novel-N-625',
#  'ENGLISH CUSTOMS': 'novel-N-626',
#  'REMOTE NATIONS': 'novel-N-627',
#  'PHILOLOGISTS': 'novel-N-628',
#  'ETHNOLOGISTS': 'novel-N-629',
#  'TOWER OF BABEL': 'novel-N-630',
#  'LEARNED RABBINS': 'novel-N-631',
#  'PRIESTS OF MAYAB': 'novel-N-632',
#  'EVENING': 'novel-N-633',
#  'MORNING': 'novel-N-634',
#  'SIXTY-NINE': 'novel-N-635',
#  'TAMMY': 'novel-N-636',
#  'SIEVE': 'novel-N-637',
#  'ENGLISH': 'novel-N-638',
#  'JANUARY 28, 1873': 'novel-N-639',
#  'NEW YORK AMERICAN GEOGRAPHICAL SOCIETY': 'novel-N-640',
#  'AMERICA': 'novel-N-641',
#  'EGYPT': 'novel-N-642',
#  'SUN CIRCLES': 'novel-N-643',
#  'DOLMEN': 'novel-N-644',
#  'TUMULI': 'novel-N-645',
#  'AMERICAN MEGALITHIC MONUMENTS': 'novel-N-646',
#  'PACIFIC ISLANDS': 'novel-N-647',
#  'HINDOSTAN': 'novel-N-648',
#  'SOUTH ASIA': 'novel-N-649',
#  'ARABIA': 'novel-N-650',
#  'NORTH AFRICA': 'novel-N-651',
#  'PRIMITIVE AGE': 'novel-N-652',
#  'ADVANCED CIVILIZATION': 'novel-N-653',
#  'AMERICAN CONTINENT': 'novel-N-654',
#  'VALLEY OF THE NILE': 'novel-N-655',
#  'MOUND BUILDERS': 'novel-N-656',
#  'PLAINS OF ASIA': 'novel-N-657',
#  'MOUNDS': 'novel-N-658',
#  'MISSISSIPPI VALLEY': 'novel-N-659',
#  'NILE VALLEY': 'novel-N-660',
#  'ARCHITECTURE': 'novel-N-661',
#  'VALMIKI': 'novel-N-662',
#  'RAMAYANA': 'novel-N-663',
#  '1500 BCE': 'novel-N-664',
#  'RAMA': 'novel-N-665',
#  'SITA': 'novel-N-666',
#  'SILVER': 'novel-N-667',
#  'GOLD': 'novel-N-668',
#  'PRECIOUS STONES': 'novel-N-669',
#  'LAPIS LAZULI': 'novel-N-670',
#  'VINDHYA MOUNTAINS': 'novel-N-671',
#  'PRASTRAVANA RANGE': 'novel-N-672',
#  'FOREIGNERS': 'novel-N-673',
#  'MAYAS TERRITORIES': 'novel-N-674',
#  'LACANDONES': 'novel-N-675',
#  'LA TIERRA DE GUERRA': 'novel-N-676',
#  'IMMIGRATION': 'novel-N-677',
#  'DAVANAS': 'novel-N-678',
#  'HEMA': 'novel-N-679',
#  'POURANDURA': 'novel-N-680',
#  'HEM': 'novel-N-681',
#  'AAC': 'novel-N-682',
#  'LAW OF THE COUNTRY': 'novel-N-683',
#  "MURAL PAINTINGS OF CHAACMOL'S FUNERAL CHAMBER": 'novel-N-684',
#  'SCULPTURES OF CHICHEN': 'novel-N-685',
#  'SPEAR': 'novel-N-686',
#  'MR. H. T. COLEBROOKE': 'novel-N-687',
#  'SACRED BOOKS OF THE HINDOOS': 'novel-N-688',
#  'ASIATIC RESEARCHES': 'novel-N-689',
#  'SOURYASIDDKANTU': 'novel-N-690',
#  'RIG-VEDA': 'novel-N-691',
#  'BRAHMA': 'novel-N-692',
#  'HIRAYAGARBHIA': 'novel-N-693',
#  'SCULPTURES AT CHICHEN-ITZA': 'novel-N-694',
#  'EMILE BURNOUF': 'novel-N-695',
#  'SANSCRIT DICTIONARY': 'novel-N-696',
#  'DITYAS': 'novel-N-697',
#  'INDIA': 'novel-N-698',
#  'HIP': 'novel-N-699',
#  'HETZMEC': 'novel-N-700',
#  'AGE OF FOUR MONTHS': 'novel-N-701',
#  'MEMBERS OF THE FAMILY': 'novel-N-702',
#  'PARENTS': 'novel-N-703',
#  'NAILAH': 'novel-N-704',
#  'HETZMEC GODMOTHER': 'novel-N-705',
#  'HOUSE': 'novel-N-706',
#  'FOUR MONTHS OLD': 'novel-N-707',
#  'GODMOTHER': 'novel-N-708',
#  'CHILD': 'novel-N-709',
#  'INDUSTRY': 'novel-N-710',
#  'MOTHER': 'novel-N-711',
#  'NORTH AMERICA': 'novel-N-712',
#  'HUMAN HAND': 'novel-N-713',
#  'RED LIQUID': 'novel-N-714',
#  'SACRED EDIFICES': 'novel-N-715',
#  'HUMAN RACE': 'novel-N-716',
#  'WESTERN CONTINENT': 'novel-N-717',
#  'EASTERN AND SOUTHERN SHORES OF ASIA': 'novel-N-718',
#  'PACIFIC OCEAN': 'novel-N-719',
#  'SOUTH SEA ISLANDERS': 'novel-N-720',
#  'FRED. P. BARLEE, ESQ.': 'novel-N-721',
#  'BRITISH HONDURAS': 'novel-N-722',
#  'AUSTRALIA': 'novel-N-723',
#  'ROCKS': 'novel-N-724',
#  'RED OR BLOODY HAND': 'novel-N-725',
#  'RED HAND IMPRINTS': 'novel-N-726',
#  "GOVERNOR'S HOUSE AT UXMAL": 'novel-N-727',
#  'INDIAN FRIENDS': 'novel-N-728',
#  'ARCHWAY OF THE PALACE OF THE PRIESTS': 'novel-N-729',
#  'RED HAND SYMBOL': 'novel-N-730',
#  'MEDITERRANEAN': 'novel-N-731',
#  'ASSYRIANS': 'novel-N-732',
#  'ABORIGINES OF SOME PARTS OF AMERICA': 'novel-N-733',
#  'LEARNED MEN': 'novel-N-734',
#  'MR. SCHOOLCRAFT': 'novel-N-735',
#  'NEW YORK HERALD': 'novel-N-736',
#  'APRIL 12, 1879': 'novel-N-737',
#  'GEN. GRANT': 'novel-N-738',
#  'RAM SINGH': 'novel-N-739',
#  'MAHARAJAH OF JEYPOOR': 'novel-N-740',
#  'AMBER': 'novel-N-741',
#  'SMALL TEMPLES': 'novel-N-742',
#  'WHITE WALL': 'novel-N-743',
#  '2ND COLUMN': 'novel-N-744',
#  '5TH PAGE': 'novel-N-745',
#  '_NEW YORK HERALD_': 'novel-N-746',
#  'OFFERINGS OF GRAINS': 'novel-N-747',
#  'OFFERINGS OF FRUITS': 'novel-N-748',
#  'OFFERINGS OF FLOWERS': 'novel-N-749',
#  'PEOPLE AT WORSHIP': 'novel-N-750',
#  'MARKS OF THE HUMAN HAND': 'novel-N-751',
#  'BLOOD': 'novel-N-752',
#  'GODS': 'novel-N-753',
#  'VOW': 'novel-N-754',
#  'PRAYER': 'novel-N-755',
#  'RAIN': 'novel-N-756',
#  'FOOD': 'novel-N-757',
#  'HEALTH': 'novel-N-758',
#  'DEVOTEE': 'novel-N-759',
#  'HAND IMPRINTS': 'novel-N-760',
#  'OWNERS OF THE HOUSE': 'novel-N-761',
#  'PUBLIC BUILDINGS': 'novel-N-762',
#  'BLESSING': 'novel-N-763',
#  'VOWS': 'novel-N-764',
#  'SIGNET': 'novel-N-765',
#  'MARK OF PROPERTY': 'novel-N-766',
#  'MY HOUSE': 'novel-N-767',
#  'IN NAA': 'novel-N-768',
#  'RELIGIOUS RITES': 'novel-N-769',
#  'BELIEFS': 'novel-N-770',
#  'INHABITANTS OF _MAYAB_': 'novel-N-771',
#  'WORSHIP OF THE FIRE': 'novel-N-772',
#  'WORSHIP OF THE PHALLUS': 'novel-N-773',
#  'GANESA': 'novel-N-774',
#  'ELEPHANT': 'novel-N-775',
#  'SIAM': 'novel-N-776',
#  'BIRMAH': 'novel-N-777',
#  'ASIATIC PENINSULA': 'novel-N-778',
#  'COINCIDENCES': 'novel-N-779',
#  'TYPES OF THE PERSONAGES': 'novel-N-780',
#  'OBELISKS OF COPÓN': 'novel-N-781',
#  'SIAMEESES': 'novel-N-782',
#  'FIGURES OF MEN': 'novel-N-783',
#  'FIGURES OF WOMEN': 'novel-N-784',
#  'TEMPLES AT ELEPHANTA': 'novel-N-785',
#  'AMERICAN': 'novel-N-786',
#  'APPEARANCE': 'novel-N-787',
#  'FEATURES': 'novel-N-788',
#  'GANESHA': 'novel-N-789',
#  'OBELISKS OF COPAN': 'novel-N-790',
#  'ELEPHANTA': 'novel-N-791',
#  'AFGHANISTAN': 'novel-N-792',
#  'HIMALAYAS': 'novel-N-793',
#  'MAYA TRIBES': 'novel-N-794',
#  'AMERICAN-MAYA': 'novel-N-795',
#  'LONDON TIMES': 'novel-N-796',
#  'MARCH 4, 1879': 'novel-N-797',
#  'KABUL RIVER': 'novel-N-798',
#  'KABUL': 'novel-N-799',
#  'SHRINE': 'novel-N-800',
#  'IDOL': 'novel-N-801',
#  'HAND': 'novel-N-802',
#  'HISTORY OF YUCATAN': 'novel-N-803',
#  'FATHER LIZANA': 'novel-N-804',
#  'TEMPLE': 'novel-N-805',
#  'SQUARE': 'novel-N-806',
#  'DEAD': 'novel-N-807',
#  'SICK': 'novel-N-808',
#  'KAB': 'novel-N-809',
#  'BUL': 'novel-N-810',
#  'HAZARD': 'novel-N-811',
#  'WORKING HAND': 'novel-N-812',
#  'KUNAR': 'novel-N-813',
#  'GOD OF THE EARS OF CORN': 'novel-N-814',
#  'NEST OF THE EARS OF CORN': 'novel-N-815',
#  'KUU': 'novel-N-816',
#  'NAL': 'novel-N-817',
#  'KUKI-KHEL': 'novel-N-818',
#  'AKAKHEL': 'novel-N-819',
#  'KHAMBHUR KHEL': 'novel-N-820',
#  'KHEL': 'novel-N-821',
#  'KAAN': 'novel-N-822',
#  'TIE': 'novel-N-823',
#  'ROPE': 'novel-N-824',
#  'CLAN': 'novel-N-825',
#  'FEATHER': 'novel-N-826',
#  'RESERVOIR': 'novel-N-827',
#  'POND': 'novel-N-828',
#  'AKAL': 'novel-N-829',
#  'TRIBE OF THE PLEASANT': 'novel-N-830',
#  'KAMBUL': 'novel-N-831',
#  'ZAKA-KHEL': 'novel-N-832',
#  'TRIBE OF THE LOCUST': 'novel-N-833',
#  'ZAK': 'novel-N-834',
#  'ABORIGINES OF YUCATAN': 'novel-N-835',
#  '_KAMBUL_': 'novel-N-836',
#  'ASIA MINOR': 'novel-N-837',
#  'MAGI': 'novel-N-838',
#  'RABMAG': 'novel-N-839',
#  'BABYLON': 'novel-N-840',
#  'RAB-MAG': 'novel-N-841',
#  'LAB-MAC': 'novel-N-842',
#  '_AMERICAN MAYA_': 'novel-N-843',
#  'CHALDAIC DIVINITIES': 'novel-N-844',
#  'GREEK': 'novel-N-845',
#  'HERODOTUS': 'novel-N-846',
#  '_CARIANS_': 'novel-N-847',
#  '_CARAS_': 'novel-N-848',
#  '_CARIBS_': 'novel-N-849',
#  'INDIAN': 'novel-N-850',
#  'MESTIZA WOMEN': 'novel-N-851',
#  'CARIB': 'novel-N-852',
#  'ATLANTIS': 'novel-N-853',
#  'ATLANTIC': 'novel-N-854',
#  'GREECE': 'novel-N-855',
#  'MAIA': 'novel-N-856',
#  'KUBELES': 'novel-N-857',
#  'GOD': 'novel-N-858',
#  'BEL': 'novel-N-859',
#  'HINDOSTANEES': 'novel-N-860',
#  'RIG VEDA': 'novel-N-861',
#  'AMERICAN MAYA LANGUAGE': 'novel-N-862',
#  'CHALDEES': 'novel-N-863',
#  'ANCIENT INSCRIPTIONS': 'novel-N-864',
#  'ARCHITECTURAL MONUMENTS': 'novel-N-865',
#  'MODE OF WRITING': 'novel-N-866',
#  'BURIAL PLACES': 'novel-N-867',
#  'NAMES OF THEIR DIVINITIES': 'novel-N-868',
#  'ORIGIN OF THE PRIMITIVE CHALDEES': 'novel-N-869',
#  'MOON': 'novel-N-870',
#  'FOUNDERS': 'novel-N-871',
#  'CITY OF GUESTS': 'novel-N-872',
#  'HULA': 'novel-N-873',
#  'GUEST JUST ARRIVED': 'novel-N-874',
#  'LOWER MESOPOTAMIA': 'novel-N-875',
#  'SUPERPOSED PLATFORMS': 'novel-N-876',
#  'CONES': 'novel-N-877',
#  'PYRAMIDS': 'novel-N-878',
#  'CARDINAL POINTS': 'novel-N-879',
#  'MATERIALS': 'novel-N-880',
#  'CLAY': 'novel-N-881',
#  'BRICKS': 'novel-N-882',
#  'CHALDEA': 'novel-N-883',
#  'WARKA': 'novel-N-884',
#  'MUGHEIR': 'novel-N-885',
#  'HEWN STONE WALLS': 'novel-N-886',
#  'GRAND EXTERIOR STAIRCASES': 'novel-N-887',
#  'SUMMIT': 'novel-N-888',
#  'SHRINE OF THE GOD': 'novel-N-889',
#  'SEVEN': 'novel-N-890',
#  'SANCTUARY': 'novel-N-891',
#  'TWO CHAMBERS': 'novel-N-892',
#  'SANCTUM SANCTORUM': 'novel-N-893',
#  'BIRS-I-NIMRUD': 'novel-N-894',
#  'TEMPLE OF THE SEVEN LIGHTS': 'novel-N-895',
#  'SEVEN STAGES': 'novel-N-896',
#  'PLATFORMS': 'novel-N-897',
#  'CRUDE OR SUN-DRIED BRICKS': 'novel-N-898',
#  'UNHEWN STONES': 'novel-N-899',
#  'HEWN STONES': 'novel-N-900',
#  'SEVEN SUPERPOSED PLATFORMS': 'novel-N-901',
#  'INNER CHAMBER': 'novel-N-902',
#  'SEVEN STAGES OR PLATFORMS': 'novel-N-903',
#  'MR. LOFTUS': 'novel-N-904',
#  'CHALDEAN BUILDINGS': 'novel-N-905',
#  'ARCHED CHAMBERS': 'novel-N-906',
#  'MR. TAYLOR': 'novel-N-907',
#  'YUCATAN MONUMENTS': 'novel-N-908',
#  'TRIANGULAR ARCHES': 'novel-N-909',
#  'EGYPTIAN BUILDINGS': 'novel-N-910',
#  'SCYTHIAN TOMBS': 'novel-N-911',
#  'BRICK VAULTS': 'novel-N-912',
#  'SIDE WALLS': 'novel-N-913',
#  'BRICK': 'novel-N-914',
#  'APERTURE': 'novel-N-915',
#  'SEPULCHERS': 'novel-N-916',
#  'JAR TOMBS': 'novel-N-917',
#  'TWO LARGE OPEN-MOUTHED JARS': 'novel-N-918',
#  'BITUMEN': 'novel-N-919',
#  'DISHES': 'novel-N-920',
#  'VASES': 'novel-N-921',
#  'AIR HOLE': 'novel-N-922',
#  'STONE URNS': 'novel-N-923',
#  'EXTENSIVE MOUNDS': 'novel-N-924',
#  'THIN WALLS OF MASONRY': 'novel-N-925',
#  'RIGHT ANGLES': 'novel-N-926',
#  'LOWER PLAINS OF CHALDEA': 'novel-N-927',
#  'COAST OF PERU': 'novel-N-928',
#  'URNS': 'novel-N-929',
#  'THREE FEET SQUARE': 'novel-N-930',
#  'MASONRY WALLS': 'novel-N-931',
#  'ABBA': 'novel-N-932',
#  'CLOAK': 'novel-N-933',
#  'LINEN': 'novel-N-934',
#  'SHOULDERS': 'novel-N-935',
#  'COSTUME': 'novel-N-936',
#  'INHABITANTS OF THE TIERRA DE GUERRA': 'novel-N-937',
#  'BAND OF CLOTH': 'novel-N-938',
#  'MOTHER-OF-PEARL': 'novel-N-939',
#  "CAMEL'S HAIR": 'novel-N-940',
#  'CHALDEE': 'novel-N-941',
#  'BAND': 'novel-N-942',
#  'STATUE OF CHAAC MOL': 'novel-N-943',
#  'HIGHER CLASSES': 'novel-N-944',
#  'LONG ROBE': 'novel-N-945',
#  'FRINGE': 'novel-N-946',
#  'NECK': 'novel-N-947',
#  'FEET': 'novel-N-948',
#  'WAIST': 'novel-N-949',
#  'SHOULDER': 'novel-N-950',
#  'ARM': 'novel-N-951',
#  'DRESS': 'novel-N-952',
#  'JACKET': 'novel-N-953',
#  'HIPS': 'novel-N-954',
#  'BRACELETS': 'novel-N-955',
#  'EARRINGS': 'novel-N-956',
#  'ARMLETS': 'novel-N-957',
#  'ANKLETS': 'novel-N-958',
#  'CANON RAWLINSON': 'novel-N-959',
#  'LETTERS PROPER': 'novel-N-960',
#  'MONOGRAMS': 'novel-N-961',
#  'DETERMINATIVE': 'novel-N-962',
#  'MONUMENTAL INSCRIPTIONS': 'novel-N-963',
#  'PICTORIAL': 'novel-N-964',
#  'RELIGION OF THE MAYAS': 'novel-N-965',
#  'RELIGION OF THE PRIMITIVE CHALDEES': 'novel-N-966',
#  'POLYTHEISM': 'novel-N-967',
#  'SCHOLARS': 'novel-N-968',
#  'ESOTERIC EXPLANATIONS': 'novel-N-969',
#  'POWERS OF NATURE': 'novel-N-970',
#  'PANTHEON': 'novel-N-971',
#  'MONOTHEISM': 'novel-N-972',
#  'RA': 'novel-N-973',
#  'CIRCLE': 'novel-N-974',
#  "BABYLON'S NATIVE NAME": 'novel-N-975',
#  '_KA-RA_': 'novel-N-976',
#  'LA': 'novel-N-977',
#  'TRUTH PAR EXCELLENCE': 'novel-N-978',
#  'TRUTH': 'novel-N-979',
#  'ANA OR DIS': 'novel-N-980',
#  'THE ORIGINAL CHIEF': 'novel-N-981',
#  'THE FATHER OF THE GODS': 'novel-N-982',
#  'THE LORD OF DARKNESS OR DEATH': 'novel-N-983',
#  'A': 'novel-N-984',
#  'THY': 'novel-N-985',
#  'NA': 'novel-N-986',
#  'DIS': 'novel-N-987',
#  'ERECH': 'novel-N-988',
#  'CITY OF THE DEAD': 'novel-N-989',
#  'NECROPOLIS OF LOWER BABYLONIA': 'novel-N-990',
#  'TIX': 'novel-N-991',
#  'CAVITY FORMED IN THE EARTH': 'novel-N-992',
#  'NIFFER': 'novel-N-993',
#  'CALNEH': 'novel-N-994',
#  'SEPTUAGINT': 'novel-N-995',
#  'KAL-ANA': 'novel-N-996',
#  'FORT OF ANA': 'novel-N-997',
#  'PRISON OF ANA': 'novel-N-998',
#  'KAL': 'novel-N-999',
#  ...}

# %%
total_edges = sum(len(node.edges) for node in novel_nodes.values())//2
print("Total edges:", total_edges)
# Out:
# Total edges: 222960

# %%
def shallow_ppr_local(nodes_dict, entry_id, alpha = 0.5, t = 2, k = 10):
    #simulate a random walk with restarts, number of steps t, probability to stop at each node after stepping is alpha
    pi = dict()   # PPR scores: probability that the walk ends at each node
    r = {entry_id: 1.0}  # probability that the next step move to the node. at step 0, probability is 1 to move to entry node

    for _ in range(t): 
        r_next = dict()
        for node_id, residual in r.items(): #step to next node if probability residual
            pi[node_id] = pi.get(node_id, 0) + alpha * residual #increase PPR score by the probability of stopping here after step
            push_val = (1 - alpha) * residual #probability to continue walking (the remaining probability)
            node = nodes_dict[node_id]
            total_weight = node.degree
            if total_weight == 0: #stop if no neighbors (won't happen in undirected graph)
                continue
            for nbr_id, w in node.edges.items(): 
                r_next[nbr_id] = r_next.get(nbr_id, 0) + push_val * (w / total_weight) #probability to move to the neighbor using edge weight
        r = r_next
    #add remaining residual probabilities to PPR scores
    for node_id, residual in r.items():
        pi[node_id] = pi.get(node_id, 0) + residual
    top_nodes = sorted(pi.items(), key=lambda x: x[1], reverse=True)[:k]
    return dict(top_nodes)

shallow_ppr_local(novel_nodes, entry_id="novel-N-0")
# Out:
# {'novel-N-0': 0.6333333333333333,
#  'novel-0-S-0': 0.08333333333333333,
#  'novel-0-S-0-R-0': 0.08333333333333333,
#  'novel-0-S-0-R-2': 0.08333333333333333,
#  'novel-N-1': 0.049999999999999996,
#  'novel-N-8': 0.016666666666666666,
#  'novel-N-2': 0.008333333333333333,
#  'novel-N-3': 0.008333333333333333,
#  'novel-N-4': 0.008333333333333333,
#  'novel-N-5': 0.008333333333333333}

# %%
import networkx as nx

G = nx.Graph()
for node_id, node in medical_nodes.items():
    G.add_node(node_id, node_type=node.node_type, content=node.content, source=node.source)
    for target_id, weight in node.edges.items():
        if target_id in medical_nodes:
            G.add_edge(node_id, target_id, weight=weight)

nx.write_gml(G, "viz/medical_graph.gml")

# %%
G = nx.Graph()
for node_id, node in novel_nodes.items():
    G.add_node(node_id, node_type=node.node_type, content=node.content, source=node.source)
    for target_id, weight in node.edges.items():
        if target_id in novel_nodes:
            G.add_edge(node_id, target_id, weight=weight)

nx.write_gml(G, "viz/novel_graph.gml")
