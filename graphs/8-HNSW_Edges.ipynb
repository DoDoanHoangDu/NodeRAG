# %% [markdown]
# # Notebook 8: Add HNSW Edges
#
# This notebook constructs an HNSW index from node embeddings to quickly approximate the K-nearest neighbors (KNN) for each node.
#
# Each node is then linked with its **8 nearest neighbors**. Neighbors with a **similarity ≤ 0.6** are skipped.
#
# ## HNSW Hyperparameters
# - **M** = 32
# - **efConstruction** = 200
# - **efSearch** = 64
#
# ## Output
# - The resulting **HNSW index** is saved.
# - The resulting graph is saved as **G5 - semantically enriched graph**.

# %%
import os
dir_path = os.getcwd()
print("The directory of this script is:", dir_path)
root_path = os.path.dirname(dir_path)
print("The root directory is:", root_path)
# Out:
# The directory of this script is: c:\Users\HP\Desktop\Projects\NodeRAG\graphs
# The root directory is: c:\Users\HP\Desktop\Projects\NodeRAG

# %%
import sys
sys.path.append(root_path)
from graphs.Node import Node

# %%
import pickle
with open(f"{root_path}/graphs/data/graphs/G4_text_inserted_graph.pkl", "rb") as f:
    medical_g4 = pickle.load(f)

# %%
#sanity check
for node_id in medical_g4:
    node = medical_g4[node_id]
    for edge in node.edges:
        if node.edges[edge] > 1:
            print(node_id,"-",edge,"-",node.edges[edge])
print("-"*40)
for node_id in medical_g4:
    node = medical_g4[node_id]
    for edge in node.edges:
        if edge == node_id:
            print(node_id)
print("-"*40)
#calculate total edge weight
sum_edge = 0
for node_id in medical_g4:
    node = medical_g4[node_id]
    for edge in node.edges:
        sum_edge += node.edges[edge]
print("Total edge weight in G4:", sum_edge)
print("-"*40)
# Out:
# ----------------------------------------
# ----------------------------------------
# Total edge weight in G4: 145760
# ----------------------------------------

# %%
import json
import faiss
import numpy as np
#embeddings of S,A,H,T nodes

#load faiss index file
index = faiss.read_index("data/embedding/medical_index.faiss")
with open("data/embedding/medical_ids.json", "r") as f:
    medical_embedding_ids = json.load(f)
index.ntotal, len(medical_embedding_ids)

#reconstruct vectors from faiss index
num_vectors = index.ntotal
dimension = index.d
embeddings = np.zeros((num_vectors, dimension), dtype='float32')
for i in range(num_vectors):
    embeddings[i] = index.reconstruct(i)

print("Embeddings shape:", embeddings.shape)
embeddings
# Out:
# Embeddings shape: (4016, 768)
# array([[-0.07040366, -0.0460059 , -0.03309077, ..., -0.04978694,
#         -0.03295664, -0.00608065],
#        [-0.03963271, -0.0726626 , -0.06257651, ..., -0.0454145 ,
#         -0.03274148, -0.00346303],
#        [ 0.00135392,  0.0302959 ,  0.02910572, ...,  0.01070352,
#         -0.02824946, -0.05189522],
#        ...,
#        [ 0.04048249, -0.0287718 , -0.03389297, ..., -0.00295302,
#          0.0417009 ,  0.00099732],
#        [ 0.00630151, -0.01392328, -0.01267361, ..., -0.09236691,
#          0.01060563, -0.01778928],
#        [ 0.01245843, -0.01854508, -0.01106029, ..., -0.08220403,
#          0.01130273,  0.05532239]], dtype=float32)

# %%
import time
import random
#build hnsw index
start_time = time.time()
M = 32
hnsw = faiss.IndexHNSWFlat(embeddings.shape[1], M, faiss.METRIC_INNER_PRODUCT)
hnsw.hnsw.efConstruction = 200
hnsw.hnsw.efSearch = 64
hnsw.add(embeddings)
faiss.write_index(hnsw, "data/embedding/medical_index_hnsw.faiss")
end_time = time.time()
print(f"HNSW index built in {end_time - start_time:.2f} seconds.")

#test

k_test = 8
q = embeddings[random.randint(0,embeddings.shape[0]-1)].reshape(1, -1)
distance, idx = hnsw.search(q, k_test)
for i in range(k_test):
    print(f"Neighbor {medical_embedding_ids[i]}: Index={idx[0][i]}, Similarity={distance[0][i]}")
# Out:
# HNSW index built in 0.26 seconds.
# Neighbor medical-0-S-0: Index=2257, Similarity=1.0
# Neighbor medical-0-S-1: Index=2855, Similarity=0.6834208965301514
# Neighbor medical-0-S-2: Index=1290, Similarity=0.6249901652336121
# Neighbor medical-1-S-0: Index=1315, Similarity=0.6082144975662231
# Neighbor medical-1-S-1: Index=2758, Similarity=0.5817054510116577
# Neighbor medical-1-S-2: Index=1726, Similarity=0.5681164264678955
# Neighbor medical-1-S-3: Index=246, Similarity=0.5671625137329102
# Neighbor medical-2-S-0: Index=2792, Similarity=0.547724723815918

# %%
#addd hnsw edges to graph
for i in range(len(medical_embedding_ids)):
    node = medical_g4[medical_embedding_ids[i]]
    node_embedding = embeddings[i].reshape(1,-1)
    k = 8
    similarities, indices = hnsw.search(node_embedding, k+1)
    for j in range(k+1):
        neighbor_id = medical_embedding_ids[indices[0][j]]
        if neighbor_id == medical_embedding_ids[i]:
            continue
        neighbor = medical_g4[neighbor_id]
        similarity = round(similarities[0][j], 3)
        if similarity <= 0.6:
            continue
        node.link(neighbor, similarity)
        neighbor.link(node, similarity)

# %%
#calculate total edge weight after adding hnsw edges
sum_edge = 0
for node_id in medical_g4:
    node = medical_g4[node_id]
    for edge in node.edges:
        sum_edge += node.edges[edge]
print("Total edge weight:", sum_edge)
print("-"*40)
for node_id in medical_g4:
    node = medical_g4[node_id]
    for edge in node.edges:
        if edge == node_id:
            print(node_id)
# Out:
# Total edge weight: 190299.60600352287
# ----------------------------------------

# %%
with open(f"{root_path}/graphs/data/graphs/G5_semantically_enriched_graph.pkl", "wb") as f:
    pickle.dump(medical_g4, f)
with open(f"{root_path}/graphs/data/graphs/G5_semantically_enriched_graph.pkl", "rb") as f:
    medical_g5 = pickle.load(f)

# %%
#check
keys = list(medical_g5.keys())
for i in range(999):
    node_id = keys[i]
    node = medical_g5[node_id]
    for j in range(i+1, 1000):
        neighbor_id = keys[j]
        if neighbor_id in node.edges:
            print(node_id, "-", neighbor_id, "-", node.edges[neighbor_id])
# Out:
# medical-0-S-0 - medical-0-S-1 - 0.62
# medical-0-S-0 - medical-2-S-2 - 1.418
# medical-0-S-0 - medical-13-S-0 - 1.344
# medical-0-S-0 - medical-20-S-3 - 1.234
# medical-0-S-1 - medical-1-S-2 - 1.436
# medical-0-S-1 - medical-1-S-3 - 1.574
# medical-0-S-1 - medical-2-S-0 - 1.558
# medical-0-S-1 - medical-3-S-0 - 0.637
# medical-0-S-2 - medical-1-S-0 - 1.426
# medical-0-S-2 - medical-13-S-3 - 1.812
# medical-0-S-2 - medical-13-S-4 - 0.642
# medical-0-S-2 - medical-14-S-0 - 0.61
# medical-1-S-0 - medical-13-S-3 - 1.402
# medical-1-S-0 - medical-13-S-4 - 1.502
# medical-1-S-0 - medical-14-S-0 - 1.688
# medical-1-S-2 - medical-2-S-1 - 1.326
# medical-1-S-2 - medical-15-S-3 - 0.646
# medical-1-S-3 - medical-2-S-0 - 1.944
# medical-1-S-3 - medical-2-S-1 - 1.426
# medical-1-S-3 - medical-14-S-1 - 0.653
# medical-1-S-3 - medical-20-S-4 - 1.42
# medical-2-S-0 - medical-2-S-1 - 1.392
# medical-2-S-0 - medical-20-S-4 - 1.424
# medical-2-S-1 - medical-14-S-1 - 1.406
# medical-2-S-1 - medical-16-S-1 - 1.316
# medical-2-S-1 - medical-20-S-4 - 1.454
# medical-2-S-2 - medical-3-S-0 - 1.444
# medical-2-S-2 - medical-20-S-3 - 0.629
# medical-3-S-2 - medical-4-S-0 - 1.74
# medical-3-S-2 - medical-8-S-4 - 1.366
# medical-4-S-0 - medical-8-S-4 - 0.645
# medical-4-S-0 - medical-16-S-2 - 1.392
# medical-5-S-0 - medical-7-S-2 - 1.5
# medical-5-S-0 - medical-8-S-1 - 1.476
# medical-5-S-1 - medical-6-S-0 - 1.76
# medical-5-S-1 - medical-6-S-1 - 0.712
# medical-5-S-1 - medical-7-S-1 - 0.697
# medical-5-S-1 - medical-8-S-2 - 0.743
# medical-5-S-1 - medical-8-S-3 - 0.641
# medical-6-S-0 - medical-6-S-1 - 0.699
# medical-6-S-0 - medical-7-S-1 - 0.654
# medical-6-S-0 - medical-8-S-2 - 0.734
# medical-6-S-1 - medical-6-S-2 - 0.647
# medical-6-S-1 - medical-7-S-0 - 0.703
# medical-6-S-1 - medical-8-S-2 - 1.64
# medical-6-S-2 - medical-7-S-0 - 1.746
# medical-6-S-2 - medical-8-S-2 - 1.644
# medical-7-S-0 - medical-8-S-2 - 1.636
# medical-7-S-1 - medical-8-S-3 - 1.628
# medical-7-S-2 - medical-8-S-1 - 1.924
# medical-8-S-4 - medical-8-S-5 - 1.388
# medical-8-S-5 - medical-12-S-2 - 0.619
# medical-9-S-2 - medical-9-S-3 - 1.492
# medical-9-S-2 - medical-17-S-6 - 1.842
# medical-9-S-2 - medical-18-S-0 - 1.802
# medical-9-S-3 - medical-17-S-6 - 1.436
# medical-9-S-3 - medical-18-S-0 - 1.608
# medical-9-S-4 - medical-10-S-0 - 1.598
# medical-9-S-5 - medical-10-S-1 - 1.726
# medical-10-S-2 - medical-19-S-4 - 0.633
# medical-10-S-2 - medical-20-S-1 - 0.648
# medical-11-S-1 - medical-19-S-0 - 0.69
# medical-11-S-3 - medical-12-S-0 - 1.86
# medical-11-S-3 - medical-12-S-1 - 0.693
# medical-12-S-0 - medical-12-S-1 - 0.626
# medical-13-S-0 - medical-20-S-3 - 1.524
# medical-13-S-1 - medical-13-S-2 - 0.634
# medical-13-S-1 - medical-13-S-4 - 0.7
# medical-13-S-2 - medical-15-S-3 - 1.35
# medical-13-S-2 - medical-19-S-3 - 1.37
# medical-13-S-4 - medical-14-S-0 - 1.714
# medical-14-S-1 - medical-14-S-2 - 1.316
# medical-14-S-1 - medical-15-S-1 - 0.643
# medical-14-S-1 - medical-16-S-1 - 0.632
# medical-14-S-1 - medical-20-S-4 - 1.588
# medical-14-S-2 - medical-15-S-1 - 1.8
# medical-14-S-2 - medical-15-S-2 - 1.588
# medical-14-S-2 - medical-20-S-4 - 1.394
# medical-14-S-2 - medical-20-S-5 - 1.532
# medical-15-S-1 - medical-20-S-4 - 0.651
# medical-15-S-2 - medical-20-S-4 - 0.648
# medical-15-S-2 - medical-20-S-5 - 1.788
# medical-15-S-3 - medical-20-S-4 - 1.51
# medical-15-S-3 - medical-20-S-5 - 0.606
# medical-15-S-4 - medical-20-S-4 - 0.647
# medical-16-S-1 - medical-20-S-4 - 1.45
# medical-16-S-2 - medical-17-S-1 - 1.644
# medical-16-S-2 - medical-20-S-6 - 1.476
# medical-16-S-2 - medical-21-S-3 - 0.676
# medical-17-S-0 - medical-20-S-6 - 1.422
# medical-17-S-1 - medical-17-S-3 - 0.621
# medical-17-S-1 - medical-17-S-4 - 0.639
# medical-17-S-1 - medical-17-S-5 - 0.602
# medical-17-S-1 - medical-21-S-3 - 1.392
# medical-17-S-2 - medical-17-S-4 - 1.36
# medical-17-S-3 - medical-17-S-4 - 1.25
# medical-17-S-4 - medical-17-S-5 - 1.296
# medical-17-S-6 - medical-18-S-0 - 1.888
# medical-18-S-2 - medical-19-S-1 - 1.87
# medical-19-S-4 - medical-20-S-1 - 1.568
# medical-19-S-4 - medical-20-S-6 - 1.538
# medical-20-S-1 - medical-21-S-0 - 1.584
# medical-20-S-3 - medical-20-S-7 - 0.628
# medical-20-S-3 - medical-21-S-1 - 0.657
# medical-20-S-4 - medical-20-S-5 - 0.665
# medical-20-S-6 - medical-21-S-0 - 0.704
# medical-20-S-7 - medical-21-S-1 - 1.862
# medical-20-S-7 - medical-22-S-7 - 0.617
# medical-21-S-1 - medical-22-S-7 - 0.651
# medical-21-S-2 - medical-21-S-3 - 1.44
# medical-21-S-3 - medical-22-S-1 - 0.639
# medical-22-S-7 - medical-23-S-2 - 1.296
# medical-22-S-8 - medical-23-S-0 - 1.67
# medical-22-S-9 - medical-23-S-0 - 1.666
# medical-23-S-2 - medical-23-S-3 - 1.304
